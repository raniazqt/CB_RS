# %%
#!/usr/bin/env python
# -*- coding: latin-1 -*-
import pandas as pd # pandas is a data manipulation library
import numpy as np #provides numerical arrays and functions to manipulate the arrays efficiently
import logging
import difflib
import Levenshtein as lev
from tqdm.notebook import tqdm
import multiprocessing
from gensim.models import Doc2Vec
import gensim.models.doc2vec
import gensim
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
import seaborn as sns
import matplotlib.pyplot as plt
import scipy
from scipy import spatial
import re
import movies_df_helper_functions as helper_fn
import random
import imp
from sklearn.manifold import TSNE
from sklearn.cluster import AffinityPropagation
from tabulate import tabulate
import decimal
from collections import Counter


imp.reload(helper_fn)
# %matplotlib inline

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 50)
pd.set_option('display.width', None)
#pd.set_option('display.max_colwidth', -1)

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
tqdm.pandas()
# Out:
# d:\programs\python39\lib\site-packages\tqdm\std.py:703: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
# load movies.csv
movies_file_df = pd.read_csv('generated_dataset/imdb_final_dataset.csv')

# %%
movies_file_df.describe
# Out:
# <bound method NDFrame.describe of          movie_id                       movie_name                genres  \
# 0       tt0000615               Robbery Under Arms                 Drama
# 1       tt0000630                           Hamlet                 Drama
# 2       tt0000676  Don Álvaro o la fuerza del sino                 Drama
# 3       tt0000886        Hamlet, Prince of Denmark                 Drama
# 4       tt0000941                   Locura de amor                 Drama
# ...           ...                              ...                   ...
# 187645  tt9916170                    The Rehearsal                 Drama
# 187646  tt9916270         Il talento del calabrone              Thriller
# 187647  tt9916362                            Coven  Drama,History,Horror
# 187648  tt9916538              Kuambil Lagi Hatiku                 Drama
# 187649  tt9916706                  Dankyavar Danka                Comedy
#
#                                                actor_name  \
# 0       Jim Gerald|George Merriman|Lance Vane|Arthur G...
# 1                                   Fernanda Negri Pouget
# 2                           Joaquín Carrasco|Jaime Borrás
# 3                                       Jean Mounet-Sully
# 4       Joaquín Carrasco|José Argelagués|Elvira Fremon...
# ...                                                   ...
# 187645  Kelner Macêdo|Pablo Lafuente|Julia Ianina|Germ...
# 187646  Anna Foglietta|Lorenzo Richelmy|Sergio Castell...
# 187647  Alex Brendemühl|Daniel Fanego|Amaia Aberasturi...
# 187648   Cut Mini Theo|Sahil Shah|Lala Karmela|Ria Irawan
# 187649  Ashwini Ekbote|Suvarna Kale|Makarand Anaspure|...
#
#                          director_name  \
# 0                     Charles MacMahon
# 1                       Mario Caserini
# 2                        Narciso Cuyàs
# 3                     Gérard Bourgeois
# 4       Alberto Marro|Ricardo de Baños
# ...                                ...
# 187645                 Tamar Guimaraes
# 187646                  Giacomo Cimini
# 187647                    Pablo Agüero
# 187648               Azhar Kinoi Lubis
# 187649                   Kanchan Nayak
#
#                                         writer_name
# 0                                   Rolf Boldrewood
# 1                               William Shakespeare
# 2                                    Duque de Rivas
# 3                               William Shakespeare
# 4                              Manuel Tamayo y Baus
# ...                                             ...
# 187645                 Melissa de Raaf|Lillah Halla
# 187646                             Lorenzo Collalti
# 187647                               Katell Guillou
# 187648  Rino Sarjono|Arief Ash Siddiq|Salman Aristo
# 187649                                 Sudhir Nikam
#
# [187650 rows x 6 columns]>

# %%
movies_file_df.shape
# Out:
# (187650, 6)

# %%
movies_file_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187650 entries, 0 to 187649
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   movie_id       187650 non-null  object
#  1   movie_name     187650 non-null  object
#  2   genres         187650 non-null  object
#  3   actor_name     187650 non-null  object
#  4   director_name  187650 non-null  object
#  5   writer_name    187650 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %%
movies_file_df.describe(include=['object', 'bool'])
# Out:
#          movie_id movie_name  genres    actor_name director_name  \
# count      187650     187650  187650        187650        187650
# unique     187650     170042    1134        186062         67986
# top     tt7380420     Hamlet   Drama  Peter Coyote  Sam Newfield
# freq            1         25   43943            13           202
#
#                 writer_name
# count                187650
# unique               137786
# top     William Shakespeare
# freq                    243

# %%
movies_file_df[movies_file_df['movie_id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [movie_id, movie_name, genres, actor_name, director_name, writer_name]
# Index: []

# %% [markdown]
# ***********************Prepare the movies information to be used for training the doc2vec model ***********************
# \rnsteps:
# Step 1-split actor_name, director_name,writer_name,genere_id,country_id and convert it to list of words
# #Step 2-concatenate first and last names with an _
# #Step 3.convert all data to lower case
# #Step 4-concatenate movie_id and title to overcome the issue of movies having the same title
# #Step 5-create a sentence to represent each movie by combining all attributes for every movie in one string with space separating each value

# %%
#copy data into new dataframe
movies_df = movies_file_df.copy()

# %%
movies_df['genres'] = movies_df['genres'].apply(
            lambda row: row.lower().strip().replace(' ','_').split(','))
movies_df['actor_name'] = movies_df['actor_name'].apply(
            lambda row: row.lower().strip().replace(' ','_').split('|'))
movies_df['director_name'] = movies_df['director_name'].apply(
            lambda row: row.lower().strip().replace(' ','_').split('|'))
movies_df['writer_name'] = movies_df['writer_name'].apply(
            lambda row: row.lower().strip().replace(' ','_').split('|'))
movies_df['movie_id'] = movies_df.apply(
            lambda row: row['movie_name'].lower().strip().replace(' ','_')  + '_' + row['movie_id'], axis=1)
movies_df = movies_df.rename(columns={'movie_name':'title', 'genres':'genre'})
movies_df['title']=movies_df['title'].str.lower()

# %%
#movies_df.describe(include=['object', 'bool'])

# %%
#x = movies_df['movie_name'].lower().replace(' ','_') + '_' + movies_df['movie_id']

# %%
movies_df.tail(10)
# Out:
#                                                 movie_id  \
# 95814                       three_robot_heroes_tt0334278
# 110412                              the_croods_tt0481499
# 86135                     asiye_nasil_kurtulur_tt0263072
# 129269  story_of_kale:_when_someone's_in_love_tt13081264
# 68147                          the_master_plan_tt0163738
# 112830                tres_bárbaros_en_un_jeep_tt0814361
# 61923                           the_harmonists_tt0128133
# 147593                               amsterdam_tt2397431
# 48721                     colierul_de_turcoaze_tt0088938
# 105003                   kartal_yavrusu_hamido_tt0417860
#
#                                         title                           genre  \
# 95814                      three robot heroes                [action, sci-fi]
# 110412                             the croods  [adventure, animation, comedy]
# 86135                    asiye nasil kurtulur                         [drama]
# 129269  story of kale: when someone's in love                [drama, romance]
# 68147                         the master plan                  [crime, drama]
# 112830               tres bárbaros en un jeep                        [comedy]
# 61923                          the harmonists       [biography, drama, music]
# 147593                              amsterdam                      [thriller]
# 48721                    colierul de turcoaze    [action, adventure, history]
# 105003                  kartal yavrusu hamido              [adventure, drama]
#
#                                                actor_name  \
# 95814   [sang-ok_kim, guk-hyeon_kim, ja-ho_lim, ryong_...
# 110412  [nicolas_cage, catherine_keener, emma_stone, r...
# 86135   [orçun_sonat, sükriye_atav, ahmet_arkan, türka...
# 129269  [arya_saloka, ardhito_pramono, aurélie_moerema...
# 68147   [tilda_thamar, wayne_morris, mary_mackenzie, n...
# 112830  [gabriel_aragón_'gaby', emilio_aragón_'miliki'...
# 61923   [ben_becker, heinrich_schafmeister, ulrich_noe...
# 147593  [louis_champagne, suzanne_clément, robin_auber...
# 48721   [alexandru_repan, florin_piersic, marga_barbu,...
# 105003  [abdullah_ferah, nuri_sesigüzel, asim_nipton, ...
#
#                         director_name  \
# 95814                    [ki-nam_nam]
# 110412  [kirk_demicco, chris_sanders]
# 86135                  [nejat_saydam]
# 129269        [angga_dwimas_sasongko]
# 68147                   [cy_endfield]
# 112830         [manuel_de_la_pedrosa]
# 61923              [joseph_vilsmaier]
# 147593              [stefan_miljevic]
# 48721            [gheorghe_vitanidis]
# 105003                    [ümit_utku]
#
#                                           writer_name
# 95814                                  [kwang-jae_oh]
# 110412                                  [john_cleese]
# 86135                      [vasif_ongören, safa_önal]
# 129269          [marcella_f.p., mohammad_irfan_ramly]
# 68147                                  [harald_bratt]
# 112830                             [juan_ángel_cardi]
# 61923   [jürgen_egger, jürgen_büscher, klaus_richter]
# 147593                              [louis_champagne]
# 48721                   [eugen_barbu, nicolae_mihail]
# 105003                                 [sadik_sendil]

# %%
display(tabulate(movies_df.head(), tablefmt='html'))
# Out:
# '<table>\n<tbody>\n<tr><td style="text-align: right;"> 31293</td><td>purple_noon_tt0054189                             </td><td>purple noon                            </td><td>[&#x27;crime&#x27;, &#x27;drama&#x27;, &#x27;thriller&#x27;]</td><td>[&#x27;alain_delon&#x27;, &#x27;marie_laforêt&#x27;, &#x27;maurice_ronet&#x27;, &#x27;erno_crisa&#x27;]                                                  </td><td>[&#x27;rené_clément&#x27;]      </td><td>[&#x27;paul_gégauff&#x27;, &#x27;patricia_highsmith&#x27;]</td></tr>\n<tr><td style="text-align: right;"> 91795</td><td>efkarliyim_abiler_tt0301266                       </td><td>efkarliyim abiler                      </td><td>[&#x27;comedy&#x27;, &#x27;romance&#x27;]         </td><td>[&#x27;hulusi_kentmen&#x27;, &#x27;abdullah_ferah&#x27;, &#x27;filiz_akin&#x27;, &#x27;sadri_alisik&#x27;, &#x27;ahmet_karaca&#x27;, &#x27;faik_coskun&#x27;, &#x27;hakki_haktan&#x27;]</td><td>[&#x27;türker_inanoglu&#x27;]   </td><td>[&#x27;safa_önal&#x27;]                         </td></tr>\n<tr><td style="text-align: right;">118121</td><td>christmas_with_a_prince:_becoming_royal_tt10481792</td><td>christmas with a prince: becoming royal</td><td>[&#x27;romance&#x27;]                   </td><td>[&#x27;nick_hounslow&#x27;, &#x27;josh_dean&#x27;, &#x27;kaitlyn_leeb&#x27;, &#x27;anastasia_marinina&#x27;]                                             </td><td>[&#x27;justin_g._dyck&#x27;]    </td><td>[&#x27;keith_cooper&#x27;]                      </td></tr>\n<tr><td style="text-align: right;"> 73145</td><td>baby_tsina_tt0185859                              </td><td>baby tsina                             </td><td>[&#x27;drama&#x27;]                     </td><td>[&#x27;rez_cortez&#x27;, &#x27;rolando_tinio&#x27;, &#x27;zeny_zabala&#x27;, &#x27;vilma_santos&#x27;]                                                   </td><td>[&#x27;marilou_diaz-abaya&#x27;]</td><td>[&#x27;ricardo_lee&#x27;, &#x27;william_c._leary&#x27;]   </td></tr>\n<tr><td style="text-align: right;"> 98119</td><td>n.b.t._tt0353773                                  </td><td>n.b.t.                                 </td><td>[&#x27;drama&#x27;, &#x27;sport&#x27;]            </td><td>[&#x27;peter_cunningham&#x27;, &#x27;greg_goossen&#x27;, &#x27;rick_lindland&#x27;, &#x27;adrienne_janic&#x27;]                                          </td><td>[&#x27;jimmy_nickerson&#x27;]   </td><td>[&#x27;tyson_ervin&#x27;]                       </td></tr>\n</tbody>\n</table>'

# %%
#movies_df['movie_sentence'] = movies_df.progress_apply(lambda row:  helper_fn.build_sentence_from_col(row.actor_name, row.genre, row.director_name, row.writer_name,''), axis=1)

movies_df['movie_sentence']= movies_df.actor_name + movies_df.genre + movies_df.director_name + movies_df.writer_name

# %%
#check if any movie has empty sentence
movies_df[movies_df['movie_sentence'].str.len() == 0].count()
# Out:
# movie_id          0
# title             0
# genre             0
# actor_name        0
# director_name     0
# writer_name       0
# movie_sentence    0
# dtype: int64

# %%
movies_df['movie_sentence']
# Out:
# 0         [george_merriman, lance_vane, jim_gerald, will...
# 1         [fernanda_negri_pouget, drama, mario_caserini,...
# 2         [joaquín_carrasco, jaime_borrás, drama, narcis...
# 3         [jean_mounet-sully, drama, gérard_bourgeois, w...
# 4         [josé_durany, elvira_fremont, joaquín_carrasco...
#                                 ...
# 187645    [julia_ianina, pablo_lafuente, kelner_macêdo, ...
# 187646    [marina_occhionero, sergio_castellitto, anna_f...
# 187647    [alex_brendemühl, daniel_fanego, amaia_aberast...
# 187648    [ria_irawan, sahil_shah, lala_karmela, cut_min...
# 187649    [suvarna_kale, makarand_anaspure, prakash_dhot...
# Name: movie_sentence, Length: 187650, dtype: object

# %%
movies_df[18:]
# Out:
#                                       movie_id                         title  \
# 18                            anfisa_tt0002022                        anfisa
# 19                         cleopatra_tt0002101                     cleopatra
# 20                   dante's_inferno_tt0002130               dante's inferno
# 21      the_great_circus_catastrophe_tt0002153  the great circus catastrophe
# 22                               eva_tt0002163                           eva
# ...                                        ...                           ...
# 187645                 the_rehearsal_tt9916170                 the rehearsal
# 187646      il_talento_del_calabrone_tt9916270      il talento del calabrone
# 187647                         coven_tt9916362                         coven
# 187648           kuambil_lagi_hatiku_tt9916538           kuambil lagi hatiku
# 187649               dankyavar_danka_tt9916706               dankyavar danka
#
#                               genre  \
# 18                          [drama]
# 19                 [drama, history]
# 20      [adventure, drama, fantasy]
# 21                          [drama]
# 22                          [drama]
# ...                             ...
# 187645                      [drama]
# 187646                   [thriller]
# 187647     [drama, history, horror]
# 187648                      [drama]
# 187649                     [comedy]
#
#                                                actor_name  \
# 18              [vladimir_shaternikov, vladimir_maksimov]
# 19      [pearl_sindelar, miss_robson, charles_sindelar...
# 20      [arturo_pirovano, giuseppe_de_liguoro, pier_de...
# 21      [alma_hinding, axel_mattsson, frederik_christe...
# 22      [hans_marr, harry_liedtke, frida_richard, henn...
# ...                                                   ...
# 187645  [julia_ianina, pablo_lafuente, kelner_macêdo, ...
# 187646  [marina_occhionero, sergio_castellitto, anna_f...
# 187647  [alex_brendemühl, daniel_fanego, amaia_aberast...
# 187648  [ria_irawan, sahil_shah, lala_karmela, cut_min...
# 187649  [suvarna_kale, makarand_anaspure, prakash_dhot...
#
#                                 director_name  \
# 18                         [yakov_protazanov]
# 19                       [charles_l._gaskill]
# 20      [adolfo_padovan, francesco_bertolini]
# 21                [eduard_schnedler-sørensen]
# 22                            [curt_a._stark]
# ...                                       ...
# 187645                      [tamar_guimaraes]
# 187646                       [giacomo_cimini]
# 187647                         [pablo_agüero]
# 187648                    [azhar_kinoi_lubis]
# 187649                        [kanchan_nayak]
#
#                                             writer_name  \
# 18                                    [leonid_andreyev]
# 19                                   [victorien_sardou]
# 20                                    [dante_alighieri]
# 21                                     [alfred_kjerulf]
# 22                                        [richard_voß]
# ...                                                 ...
# 187645                  [lillah_halla, melissa_de_raaf]
# 187646                               [lorenzo_collalti]
# 187647                                 [katell_guillou]
# 187648  [arief_ash_siddiq, salman_aristo, rino_sarjono]
# 187649                                   [sudhir_nikam]
#
#                                            movie_sentence
# 18      [vladimir_shaternikov, vladimir_maksimov, dram...
# 19      [pearl_sindelar, miss_robson, charles_sindelar...
# 20      [arturo_pirovano, giuseppe_de_liguoro, pier_de...
# 21      [alma_hinding, axel_mattsson, frederik_christe...
# 22      [hans_marr, harry_liedtke, frida_richard, henn...
# ...                                                   ...
# 187645  [julia_ianina, pablo_lafuente, kelner_macêdo, ...
# 187646  [marina_occhionero, sergio_castellitto, anna_f...
# 187647  [alex_brendemühl, daniel_fanego, amaia_aberast...
# 187648  [ria_irawan, sahil_shah, lala_karmela, cut_min...
# 187649  [suvarna_kale, makarand_anaspure, prakash_dhot...
#
# [187632 rows x 7 columns]

# %%
movies_df[movies_df['title'] =='lord of the ring']
# Out:
# Empty DataFrame
# Columns: [movie_id, title, genre, actor_name, director_name, writer_name, movie_sentence]
# Index: []

# %%
movies_df.to_csv('../models/exp4/imdb_doc2vec_train_data.csv')

# %%
x = movies_df['movie_sentence'].str
x

# %%
print(x)

# %% [markdown]
# # ********************************* Create the doc2vec model **********************

# %%
# Create the tagged document needed for Doc2Vec
tagged_documents=[]
movies_df.progress_apply(lambda row : tagged_documents.append(TaggedDocument(row.movie_sentence,[row.movie_id])),axis=1)

#convert the series of tagged docuemnt to a list
train_data = list(tagged_documents)

print("Length of training data {}".format(len(train_data)))
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=187650.0), HTML(value='')))
# Length of training data 187650

# %%
train_data
# Out:
# [TaggedDocument(words=['george_merriman', 'lance_vane', 'jim_gerald', 'william_duff', 'rhoda_dendron', 'arthur_guest', 'drama', 'charles_macmahon', 'rolf_boldrewood'], tags=['robbery_under_arms_tt0000615']),
#  TaggedDocument(words=['fernanda_negri_pouget', 'drama', 'mario_caserini', 'william_shakespeare'], tags=['hamlet_tt0000630']),
#  TaggedDocument(words=['joaquín_carrasco', 'jaime_borrás', 'drama', 'narciso_cuyàs', 'duque_de_rivas'], tags=['don_álvaro_o_la_fuerza_del_sino_tt0000676']),
#  TaggedDocument(words=['jean_mounet-sully', 'drama', 'gérard_bourgeois', 'william_shakespeare'], tags=['hamlet,_prince_of_denmark_tt0000886']),
#  TaggedDocument(words=['josé_durany', 'elvira_fremont', 'joaquín_carrasco', 'josé_argelagués', 'drama', 'ricardo_de_baños', 'alberto_marro', 'manuel_tamayo_y_baus'], tags=['locura_de_amor_tt0000941']),
#  TaggedDocument(words=['maria_caserini', 'dante_cappelli', 'drama', 'mario_caserini', 'william_shakespeare'], tags=['amleto_tt0001112']),
#  TaggedDocument(words=['alfred_cohn', 'aage_fønss', 'marie_niedermann', 'victor_neumann', 'philip_bech', 'peter_malberg', 'axel_garde', 'aage_bjørnbak', 'crime', 'gunnar_helsengreen', 'aage_garde'], tags=['ansigttyven_i_tt0001115']),
#  TaggedDocument(words=['jean_chameroy', 'lou_tellegen', 'paul_capellani', 'sarah_bernhardt', 'drama', 'romance', 'henri_pouctal', 'andré_calmettes', 'louis_mercanton', 'alexandre_dumas_fils'], tags=['camille_tt0001175']),
#  TaggedDocument(words=['cecilio_rodríguez_de_la_vega', 'dolores_puchol', 'adventure', 'drama', 'ricardo_de_baños', 'alberto_marro', 'víctor_balaguer'], tags=['don_juan_de_serrallonga_tt0001184']),
#  TaggedDocument(words=['emilie_sannom', 'ella_la_cour', 'axel_mattsson', 'carl_rosenbaum', 'oscar_langkilde', 'alwin_neuß', 'aage_hertel', 'einar_zangenberg', 'drama', 'august_blom', 'william_shakespeare'], tags=['hamlet_tt0001240']),
#  TaggedDocument(words=['pat_hartigan', 'charles_kent', 'julia_arthur', 'william_humphrey', 'edith_storey', 'biography', 'drama', 'family', 'j._stuart_blackton', 'rollin_s._sturgeon', 'madison_c._peters'], tags=['the_life_of_moses_tt0001285']),
#  TaggedDocument(words=['alfred_cohn', 'ellen_gottschalch', 'aage_fønss', 'philip_bech', 'peter_malberg', 'ragnhild_christensen', 'aage_bjørnbak', 'drama', 'history', 'gunnar_helsengreen', 'b.s._ingemann'], tags=['valdemar_sejr_tt0001440']),
#  TaggedDocument(words=['lottie_lyell', 'raymond_longford', 'lily_dampier', 'drama', 'alfred_rolfe', 'marcus_clarke'], tags=['the_convict_hero_tt0001731']),
#  TaggedDocument(words=['henri_étiévant', 'maria_ventura', 'henry_krauss', 'mistinguett', 'drama', 'albert_capellani', 'paul_capellani', 'victor_hugo'], tags=['les_misérables,_part_1:_jean_valjean_tt0001790']),
#  TaggedDocument(words=['gunnar_helsengreen', 'mary_hagen', 'hugo_flink', 'emil_albes', 'asta_nielsen', 'valdemar_psilander', 'drama', 'urban_gad', 'gebhard_schätzler-perasini'], tags=['den_sorte_drøm_tt0001892']),
#  TaggedDocument(words=['augustus_neville', 'charles_lawrence', 'nellie_stewart', 'stewart_clyde', 'biography', 'drama', 'history', 'raymond_longford', 'paul_kester', 'mrs._charles_a._doremus'], tags=['nell_gwynne_tt0001911']),
#  TaggedDocument(words=['max_wogritsch', 'fritz_weidemann', 'emil_albes', 'frl._stoike', 'asta_nielsen', 'hermann_seldeneck', 'drama', 'urban_gad', 'hermann_sudermann'], tags=["the_devil's_assistant_tt0001914"]),
#  TaggedDocument(words=['robert_valberg', 'emil_albes', 'albert_paul', 'max_obal', 'max_wilmsen', 'asta_nielsen', 'drama', 'urban_gad', 'erich_zeiske'], tags=['the_traitress_tt0001964']),
#  TaggedDocument(words=['vladimir_shaternikov', 'vladimir_maksimov', 'drama', 'yakov_protazanov', 'leonid_andreyev'], tags=['anfisa_tt0002022']),
#  TaggedDocument(words=['pearl_sindelar', 'miss_robson', 'charles_sindelar', 'helen_gardner', 'mr._howard', 'james_r._waite', 'miss_fielding', 'helene_costello', 'drama', 'history', 'charles_l._gaskill', 'victorien_sardou'], tags=['cleopatra_tt0002101']),
#  TaggedDocument(words=['arturo_pirovano', 'giuseppe_de_liguoro', 'pier_delle_vigne', 'salvatore_papa', 'adventure', 'drama', 'fantasy', 'adolfo_padovan', 'francesco_bertolini', 'dante_alighieri'], tags=["dante's_inferno_tt0002130"]),
#  TaggedDocument(words=['alma_hinding', 'axel_mattsson', 'frederik_christensen', 'lauritz_olsen', 'agnes_lorentzen', 'frederik_jacobsen', 'aage_hertel', 'valdemar_psilander', 'drama', 'eduard_schnedler-sørensen', 'alfred_kjerulf'], tags=['the_great_circus_catastrophe_tt0002153']),
#  TaggedDocument(words=['hans_marr', 'harry_liedtke', 'frida_richard', 'henny_porten', 'drama', 'curt_a._stark', 'richard_voß'], tags=['eva_tt0002163']),
#  TaggedDocument(words=['emilie_otterdahl', 'stella_lind', 'kirstine_friis-hjorth', 'rasmus_ottesen', 'charles_løwaas', 'richard_jensen', 'lili_beck', 'drama', 'alfred_lind', 'carl_otto_dumreicher'], tags=['the_flying_circus_tt0002186']),
#  TaggedDocument(words=['hilmar_clausen', 'alma_hinding', 'aage_lorentzen', 'carl_lauritzen', 'cajus_bruun', 'anton_gambetta_salmson', 'agnes_lorentzen', 'valdemar_psilander', 'romance', 'robert_dinesen', 'thomas_p._krag'], tags=['den_glade_løjtnant_tt0002211']),
#  TaggedDocument(words=['art_acord', 'william_eagle_shirt', 'ray_myers', 'ann_little', 'francis_ford', 'ethel_grandin', 'western', 'thomas_h._ince', 'c._gardner_sullivan'], tags=['the_invaders_tt0002281']),
#  TaggedDocument(words=['tim_howard', 'dorothy_judge', 'robert_henry', 'jack_goodall', 'd.l._dalziel', 'nellie_kemberman', 'j._barry', 'drama', 'raymond_longford', 'walter_howard'], tags=['the_midnight_wedding_tt0002361']),
#  TaggedDocument(words=['willie_west', 'flora_morris', 'mr._rivary', 'harry_royston', 'alma_taylor', 'ivy_millais', 'john_mcmahon', 'drama', 'thomas_bentley', 'charles_dickens'], tags=['oliver_twist_tt0002406']),
#  TaggedDocument(words=['eduard_von_winterstein', 'harry_liedtke', 'pola_negri', 'emil_jannings', 'biography', 'drama', 'romance', 'ernst_lubitsch', 'hanns_kräly', 'norbert_falk'], tags=['passion_tt0002423']),
#  TaggedDocument(words=['carlo_cattaneo', 'gustavo_serena', 'amelia_cattaneo', 'amleto_novelli', 'drama', 'history', 'enrico_guazzoni', 'henryk_sienkiewicz'], tags=['quo_vadis?_tt0002445']),
#  TaggedDocument(words=['constantin_nottara', 'constanta_demetriade', 'aristide_demetriade', 'pepi_machauer', 'history', 'war', 'grigore_brezeanu', 'petre_liciu'], tags=['the_independence_of_romania_tt0002452']),
#  TaggedDocument(words=['robert_gemp', 'james_keane', 'albert_gardner', 'frederick_warde', 'drama', 'andré_calmettes', 'william_shakespeare'], tags=['the_life_and_death_of_king_richard_iii_tt0002461']),
#  TaggedDocument(words=['alois_sedlácek', 'karel_vána', 'jára_sedlácek', 'anna_sedlácková', 'rudolf_matucha', 'josef_rozsíval', 'comedy', 'max_urban', 'william_shakespeare'], tags=['saty_delaji_cloveka_tt0002474']),
#  TaggedDocument(words=['john_ekman', 'gunnel_holzhausen', 'gunnar_norberg', 'victor_sjöström', 'lili_beck', 'drama', 'mauritz_stiller', 'charles_magnusson', 'sigrid_calamnius'], tags=['saved_in_mid-air_tt0002514']),
#  TaggedDocument(words=['elemér_thury', 'antal_nyáray', 'béla_bodonyi', 'zoltán_sipos', 'drama', 'romance', 'michael_curtiz', 'zsolt_harsányi'], tags=['the_last_bohemian_tt0002555']),
#  TaggedDocument(words=['josette_andriot', 'olga_demidoff', 'émile_keppens', 'andré_liabel', 'paul_guidé', 'alexandre_arquillière', 'charles_krauss', 'crime', 'thriller', 'victorin-hippolyte_jasset', 'léon_sazie'], tags=['zigomar_contre_nick_carter_tt0002588']),
#  TaggedDocument(words=['horace_b._carpenter', 'charles_clary', 'lafe_mckee', 'tom_santschi', 'kathlyn_williams', 'adventure', 'francis_j._grandon', 'gilson_willets', 'harold_mcgrath'], tags=['the_adventures_of_kathlyn_tt0002605']),
#  TaggedDocument(words=['nelly_ridon', 'albert_bassermann', 'hanni_weisse', 'emmerich_hanus', 'drama', 'thriller', 'max_mack', 'hippolyte_taine', 'paul_lindau'], tags=['der_andere_tt0002628']),
#  TaggedDocument(words=['carl_knudsen', 'georg_christensen', 'gyda_aller', 'bernhard_lehmann', 'doris_johannessen', 'drama', 'alfred_cohn', 'ljut_steensgaard', 'erling_stensgaard'], tags=['the_heir_to_skjoldborg_tt0002642']),
#  TaggedDocument(words=['olaf_fønss', 'carl_lauritzen', 'ebba_thomsen', 'ida_orloff', 'drama', 'august_blom', 'axel_garde', 'karl-ludwig_schröder', 'gerhart_hauptmann'], tags=['atlantis_tt0002646']),
#  TaggedDocument(words=['alexander_moissi', 'grete_berger', 'jean_ducret', 'lothar_körner', 'emil_albes', 'maria_carlotta', 'paul_wegener', 'drama', 'stellan_rye', 'hanns_heinz_ewers'], tags=["old_brandis'_eyes_tt0002648"]),
#  TaggedDocument(words=['ann_little', 'willard_mack', 'charles_edler', 'joe_king', 'drama', 'war', 'charles_giblyn', 'thomas_h._ince', 'charles_brown', 'richard_v._spencer', 'c._gardner_sullivan'], tags=['the_battle_of_gettysburg_tt0002669']),
#  TaggedDocument(words=['john_ince', 'edgar_jones', "peggy_o'neil", 'ferdinand_tidmarsh', 'blanche_west', 'john_smiley', 'robert_drouet', 'drama', 'war', 'joseph_w._smiley', 'emmett_c._hall'], tags=['the_battle_of_shiloh_tt0002670']),
#  TaggedDocument(words=['gertrude_shipman', 'thomas_w._ross', 'katherine_la_salle', 'jack_regan', 'comedy', 'drama', 'augustus_thomas', 'lawrence_b._mcgill', 'henry_martyn_blossom', 'eustace_hale_ball'], tags=['checkers_tt0002746']),
#  TaggedDocument(words=['murdock_macquarrie', "james_o'neill", "nance_o'neil", 'drama', 'history', 'joseph_a._golden', 'edwin_s._porter', 'alexandre_dumas', 'charles_fechter'], tags=['the_count_of_monte_cristo_tt0002767']),
#  TaggedDocument(words=['pauline_polaire', 'henry_roussel', 'mme._van_doren', 'fernande_petit', 'maurice_de_féraudy', 'polaire', 'charles_krauss', 'comedy', 'maurice_tourneur', 'gyp'], tags=['le_dernier_pardon_tt0002798']),
#  TaggedDocument(words=['fred_morgan', 'blanche_forsythe', 'fred_paul', 'may_morton', 'rachel_de_solla', 'drama', 'bert_haldane', 'harry_engholm', 'mrs._henry_wood'], tags=['east_lynne_tt0002820']),
#  TaggedDocument(words=['ronald_everett', 'ethel_jewett', 'george_henry', 'drama', 'will_louis', 'florence_maule_cooley', 'b.p._schulberg', 'lotta_woods'], tags=['what_80_million_women_want_tt0002822']),
#  TaggedDocument(words=['m.e._hannefy', 'john_t._carleton', 'edward_p._sullivan', 'arthur_morrison', 'laura_lyman', 'drama', 'william_cavanaugh', 'marguerite_marquis', 'henry_wadsworth_longfellow'], tags=['evangeline_tt0002832']),
#  TaggedDocument(words=['grete_berger', 'jean_ducret', 'lothar_körner', 'frank_braun', 'olly_klein', 'hans_mierendorff', 'victor_colani', 'crime', 'drama', 'stellan_rye', 'hanns_heinz_ewers'], tags=['evinrude_tt0002833']),
#  TaggedDocument(words=['rené_navarre', 'renée_carl', 'georges_melchior', 'edmund_breon', 'crime', 'drama', 'louis_feuillade', 'pierre_souvestre', 'marcel_allain'], tags=['fantômas:_in_the_shadow_of_the_guillotine_tt0002844']),
#  TaggedDocument(words=['henry_roussel', 'fernande_petit', 'henri_gouget', 'maurice_de_féraudy', 'edmond_duquesne', 'pierre_delmonde', 'charles_krauss', 'short', 'joseph_faivre', 'maurice_tourneur', 'georges_courteline'], tags=['the_funny_regiment_tt0002889']),
#  TaggedDocument(words=['jean_jacquinet', 'sylvie', 'mévisto', 'henry_krauss', 'drama', 'albert_capellani', 'émile_zola'], tags=['germinal;_or,_the_toll_of_labor_tt0002898']),
#  TaggedDocument(words=['stina_berg', 'john_ekman', 'egil_eide', 'carl_borin', 'nils_elffors', 'drama', 'mauritz_stiller', 'émile_zola', 'peter_lykke-seest'], tags=['brother_against_brother_tt0002917']),
#  TaggedDocument(words=['johnston_forbes-robertson', 'walter_ringham', 'percy_rhodes', 's.a._cookson', 'alex_scott-gatty', 'j.h._barnes', 'drama', 'hay_plumb', 'william_shakespeare'], tags=['hamlet_tt0002922']),
#  TaggedDocument(words=['lili_hajnóczy', 'gyula_szöreghy', 'adél_marosi', 'gerö_mály', 'comedy', 'michael_curtiz', 'nándor_korcsmáros', 'frigyes_hervay'], tags=["my_husband's_getting_married_tt0002996"]),
#  TaggedDocument(words=['house_peters', 'george_moss', 'david_wall', 'grace_henderson', 'mary_pickford', 'crime', 'drama', 'edwin_s._porter', 'j._searle_dawley', 'b.p._schulberg', 'miriam_michelson'], tags=["in_the_bishop's_carriage_tt0003006"]),
#  TaggedDocument(words=['aron_lindgren', 'erik_lindholm', 'hilda_borgström', 'richard_lund', 'georg_grönroos', 'william_larsson', 'drama', 'victor_sjöström', 'nils_krok'], tags=['ingeborg_holm_tt0003014']),
#  TaggedDocument(words=['wilhelm_diegelmann', 'ernst_hofmann', 'mary_dietrich', 'paul_davidson', 'erika_de_planque', 'arthur_kathane', 'gertrud_hackelberg', 'comedy', 'fantasy', 'max_reinhardt', 'arthur_kahane'], tags=['die_insel_der_seligen_tt0003015']),
#  TaggedDocument(words=['rené_navarre', 'renée_carl', 'georges_melchior', 'edmund_breon', 'crime', 'drama', 'louis_feuillade', 'pierre_souvestre', 'marcel_allain'], tags=['fantomas:_the_man_in_black_tt0003037']),
#  TaggedDocument(words=["geraldine_o'brien", 'house_peters', 'peter_lang', 'roy_pilcher', 'hal_clarendon', 'cecilia_loftus', 'drama', 'j._searle_dawley', 'frances_hodgson_burnett', 'stephen_townsend'], tags=['a_lady_of_quality_tt0003048']),
#  TaggedDocument(words=['vincent_sternroyd', 'carlotta_nillson', 'house_peters', 'alexander_gaden', 'frank_hall_crane', 'hal_clarendon', 'crime', 'drama', 'j._searle_dawley', 'c.m.s._mclellan'], tags=['leah_kleschna_tt0003056']),
#  TaggedDocument(words=['carey_l._hastings', 'lila_chester', 'james_cruze', 'maude_fealy', 'drama', 'eugene_moore', 'lloyd_lonergan', 'adelaide_anne_procter'], tags=['the_legend_of_provence_tt0003058']),
#  TaggedDocument(words=['benjamin_christensen', 'martha_hegner', 'robert_storm_petersen', 'valdemar_willumsen', 'victor_neumann', 'peter_malberg', 'henrik_malberg', 'comedy', 'elith_reumert', 'peter_nansen'], tags=['lille_klaus_og_store_klaus_tt0003069']),
#  TaggedDocument(words=['jenny_tschernichin-larsson', 'richard_lund', 'greta_pfeil', 'ivar_kåge', 'nils_aréhn', 'drama', 'victor_sjöström', 'mauritz_stiller', 'peter_lykke-seest'], tags=['livets_konflikter_tt0003076']),
#  TaggedDocument(words=['jennie_goldstein', 'drama', 'george_k._rolands', 'abraham_j._danzinger'], tags=['the_lure_of_new_york_tt0003098']),
#  TaggedDocument(words=['lyda_borelli', 'dante_cappelli', 'gian_paolo_rosmino', 'maria_caserini', 'vittorio_rossi_pianelli', 'mario_bonnard', 'drama', 'mario_caserini', 'emiliano_bonetti', 'g._monleone'], tags=['love_everlasting_tt0003102']),
#  TaggedDocument(words=['john_ekman', 'carl_borin', 'clara_pontoppidan', 'alfred_lundberg', 'justus_hagman', 'drama', 'victor_sjöström', 'émile_zola', 'martin_jørgensen', 'sven_elvestad'], tags=['miraklet_tt0003150']),
#  TaggedDocument(words=['henri_étiévant', 'maria_ventura', 'mistinguett', 'henry_krauss', 'maria_fromet', 'drama', 'albert_capellani', 'paul_capellani', 'victor_hugo'], tags=['les_misérables,_part_2:_fantine_tt0003159']),
#  TaggedDocument(words=['rené_navarre', 'andré_luguet', 'georges_melchior', 'edmund_breon', 'crime', 'drama', 'mystery', 'louis_feuillade', 'pierre_souvestre', 'marcel_allain'], tags=['fantômas:_the_dead_man_who_killed_tt0003165']),
#  TaggedDocument(words=['josephine_crowell', 'dorothy_gish', 'fay_tincher', 'spottiswoode_aitken', 'henry_b._walthall', 'lillian_gish', 'mae_marsh', 'drama', 'd.w._griffith', 'h.e._aitken'], tags=['home,_sweet_home_tt0003167']),
#  TaggedDocument(words=['james_cruze', 'harry_benham', 'william_russell', 'lila_chester', 'maude_fealy', 'gerda_holmes', 'mrs._lawrence_marston', 'drama', 'lawrence_marston', 'lloyd_lonergan', 'ouida'], tags=['moths_tt0003171']),
#  TaggedDocument(words=['gösta_ekman', 'ragnhild_ovenberg_lyche', 'jenny_tschernichin-larsson', 'grete_wiesenthal', 'drama', 'mauritz_stiller', 'hugo_von_hofmannsthal', 'karl-ludwig_schröder'], tags=['the_girl_from_abroad;_or,_the_great_underworld_tt0003227']),
#  TaggedDocument(words=['frank_young', 'drama', 'history', 'norval_macgregor', 'nell_shipman'], tags=['one_hundred_years_of_mormonism_tt0003241']),
#  TaggedDocument(words=['frazer_coulter', 'david_torrence', 'beatrice_beckley', 'james_k._hackett', 'adventure', 'hugh_ford', 'edwin_s._porter', 'anthony_hope', 'edward_e._rice'], tags=['the_prisoner_of_zenda_tt0003301']),
#  TaggedDocument(words=['stina_berg', 'emil_bergendorff', 'harry_bergvall', 'nils_elffors', 'agda_helin', 'william_larsson', 'drama', 'mauritz_stiller', 'emilie_flygare-carlén', 'peter_lykke-seest'], tags=['på_livets_ödesvägar_tt0003306']),
#  TaggedDocument(words=['rose_tapley', 'e.k._lincoln', 'sidney_drew', 'anita_stewart', 'edith_storey', 'harry_t._morey', 'charles_edwards', 'comedy', 'drama', 'george_d._baker', 'ralph_ince', 'anthony_e._wills'], tags=['a_regiment_of_two_tt0003324']),
#  TaggedDocument(words=['john_webb_dillion', 'harry_benham', 'william_russell', 'gerda_holmes', 'david_thompson', 'ernest_redding', 'mignon_anderson', 'sidney_bracey', 'adventure', 'theodore_marston', 'lloyd_lonergan'], tags=['robin_hood_tt0003337']),
#  TaggedDocument(words=['lamar_johnstone', 'arthur_cadwell_jr.', 'florence_roberts', 'shelly_hull', 'drama', 'lucius_henderson', 'alphonse_daudet', 'daniel_carson_goodman'], tags=['sapho_tt0003351']),
#  TaggedDocument(words=['varvara_yanova', 'alexandre_volkoff', 'drama', 'yakov_protazanov', 'aleksei_nikolaevich_apukhtin'], tags=['the_shattered_vase_tt0003367']),
#  TaggedDocument(words=['roy_travers', 'mrs._henry_lytton', 'fred_paul', 'blanche_forsythe', 'biography', 'bert_haldane', 'harry_engholm', 'g.b._samuelson', 'arthur_shirley', 'herbert_maxwell'], tags=['sixty_years_a_queen_tt0003379']),
#  TaggedDocument(words=['alfred_abel', 'camilla_eibenschütz', 'johanna_terwin', 'drama', 'alexander_moissi', 'hermann_sudermann'], tags=['sodoms_ende_tt0003386']),
#  TaggedDocument(words=['paul_wegener', 'grete_berger', 'lyda_salmonova', 'john_gottowt', 'drama', 'fantasy', 'horror', 'stellan_rye', 'hanns_heinz_ewers', 'alfred_de_musset'], tags=['the_student_of_prague_tt0003419']),
#  TaggedDocument(words=['robert_lawrence', 'marie_trado', 'jack_regan', 'gladys_egan', 'violet_horner', 'robert_vaughn', 'drama', 'lee_beggs', 'timothy_shay_arthur'], tags=['ten_nights_in_a_barroom_tt0003438']),
#  TaggedDocument(words=['maggie_weston', 'john_steppling', 'james_gordon', 'mary_barker', 'raymond_bond', 'minnie_maddern_fiske', 'david_torrence', 'irma_la_pierre', 'drama', 'romance', 'j._searle_dawley', 'thomas_hardy'], tags=["tess_of_the_d'urbervilles_tt0003442"]),
#  TaggedDocument(words=['carlotta_doti', 'robert_dunbar', 'gaston_bell', 'robert_whittier', 'drama', "barry_o'neil", 'charles_klein'], tags=['the_third_degree_tt0003449']),
#  TaggedDocument(words=['jane_gail', 'ethel_grandin', 'matt_moore', 'william_h._turner', 'crime', 'drama', 'george_loane_tucker', 'walter_macnamara'], tags=['traffic_in_souls_tt0003471']),
#  TaggedDocument(words=['eugenia_tettoni_fior', 'antonio_grisanti', 'fernanda_negri_pouget', 'ubaldo_stefani', 'adventure', 'drama', 'eleuterio_rodolfi', 'mario_caserini', 'edward_george_bulwer-lytton'], tags=['the_last_days_of_pompeii_tt0003489']),
#  TaggedDocument(words=['alys_collier', 'christine_rayner', 'drama', 'john_douglas', 'oliver_goldsmith'], tags=['the_vicar_of_wakefield_tt0003506']),
#  TaggedDocument(words=['warwick_buckland', 'violet_hopson', 'chrissie_white', 'harry_royston', 'marie_de_solla', 'harry_gilbey', 'drama', 'frank_wilson', 'blanche_macintosh', 'oliver_goldsmith'], tags=['the_vicar_of_wakefield_tt0003507']),
#  TaggedDocument(words=['hans_stock', 'max_laurence', 'heinrich_peer', 'hans_junkermann', 'madge_lessing', 'anna_müller-lincke', 'crime', 'max_mack', 'franz_von_schoenthan'], tags=['where_is_coletti?_tt0003565']),
#  TaggedDocument(words=['cliff_saum', 'william_cavanaugh', 'hector_dion', 'john_sharkey', 'joseph_sullivan', 'glen_white', 'charles_e._graham', 'crime', 'thriller', 'bertram_harrison', 'george_g._nathan'], tags=['the_$5,000,000_counterfeiting_plot_tt0003584']),
#  TaggedDocument(words=['millar', 'robert_warwick', 'samuel_e._hines', 'barbara_tennant', 'dorothy_dalton', 'adventure', 'drama', 'romance', 'edwin_carewe', 'charles_e._blaney'], tags=['across_the_pacific_tt0003595']),
#  TaggedDocument(words=['william_west', 'charles_ogle', 'mary_fuller', 'yale_boss', 'gladys_hulette', 'richard_neill', 'edwin_clarke', 'warren_cook', 'drama', 'walter_edwin', 'acton_davies'], tags=['the_active_life_of_dolly_of_the_dailies_tt0003596']),
#  TaggedDocument(words=['maggie_weston', 'howard_missimer', 'ida_darling', 'jack_hopkins', 'marian_swayne', 'adventure', 't._hayes_hunter', 'james_montgomery_flagg'], tags=['the_adventures_of_kitty_cobb_tt0003600']),
#  TaggedDocument(words=['robert_lawrence', 'effie_shannon', 'herbert_kelcey', 'william_clark', 'winona_bridges', 'jean_barry', 'robert_vaughn', 'drama', 'pierce_kingsley', 'charles_harris'], tags=['after_the_ball_tt0003605']),
#  TaggedDocument(words=['bert_shepherd', 'william_j._wilson', 'arthur_voegtlin', 'adventure', 'lawrence_b._mcgill', 'john_p._wilson'], tags=['america_tt0003617']),
#  TaggedDocument(words=['atila_moraes', 'conchita_de_moraes', 'sara_nobre', 'drama', 'francisco_santos', 'camilo_castelo_branco'], tags=['love_of_perdition_tt0003622']),
#  TaggedDocument(words=['vladimir_shaternikov', 'mariya_germanova', 'zoya_barantsevich', 'vladimir_kvanin', 'v._obolensky', 'mikhail_tamarov', 'drama', 'vladimir_gardin', 'leo_tolstoy'], tags=['anna_karenina_tt0003625']),
#  TaggedDocument(words=['antal_nyáray', 'aranka_molnár', 'edit_lakos', 'boriska_b._király', 'irma_lányi', 'western', 'michael_curtiz', 'bret_harte', 'ferenc_molnár'], tags=['golddigger_tt0003630']),
#  TaggedDocument(words=['edna_mayo', 'marguerite_skirvin', 'arthur_hoops', 'tyrone_power_sr.', 'william_roselle', 'ida_waterman', 'drama', 'thomas_n._heffron', 'bronson_howard'], tags=['aristocracy_tt0003631']),
#  TaggedDocument(words=['douglas_maclean', 'alice_brady', 'george_moss', 'lydia_knott', 'beverly_west', 'johnny_hines', 'edmund_mortimer', 'w.d._fischter', 'drama', 'frank_hall_crane', 'john_m._snyder'], tags=['as_ye_sow_tt0003634']),
#  TaggedDocument(words=['mrs._stuart_robson', 'rae_ford', 'esta_williams', 'madge_loomis', 'master_martin', 'arthur_morrison', 'jack_gordon', 'drama', 'frank_l._dear', 'arthur_c._aiston', 'hal_reid'], tags=['at_the_cross_roads_tt0003639']),
#  TaggedDocument(words=['robert_harron', 'ralph_lewis', 'spottiswoode_aitken', 'george_beranger', 'george_siegmann', 'blanche_sweet', 'henry_b._walthall', 'mae_marsh', 'crime', 'drama', 'horror', 'd.w._griffith', 'edgar_allan_poe'], tags=["the_avenging_conscience:_or_'thou_shalt_not_kill'_tt0003643"]),
#  TaggedDocument(words=['joseph_bailey', 'harry_spingler', 'william_bailey', 'david_wall', 'katherine_la_salle', 'william_h._tooker', 'drama', 'william_f._haddock', 'edward_m._roskam', 'bronson_howard'], tags=["the_banker's_daughter_tt0003655"]),
#  TaggedDocument(words=['j._barney_sherry', 'william_s._hart', 'clara_williams', 'joseph_j._dowling', 'j._frank_burke', 'charles_k._french', 'western', 'reginald_barker', 'william_h._clifford', 'thomas_h._ince'], tags=['the_bargain_tt0003657']),
#  TaggedDocument(words=['robert_harron', 'donald_crisp', 'fay_tincher', 'w.e._lawrence', 'mary_alden', 'lillian_gish', 'owen_moore', 'drama', 'd.w._griffith', 'daniel_carson_goodman'], tags=['the_battle_of_the_sexes_tt0003665']),
#  TaggedDocument(words=['billy_noel', 'fannie_bourke', 'madeline_fairbanks', 'al_j._jennings', 'j._morris_foster', 'albert_froom', 'frank_farrington', 'mignon_anderson', 'adventure', 'biography', 'western', 'caryl_s._fleming', 'will_irwin'], tags=['beating_back_tt0003668']),
#  TaggedDocument(words=['frank_wood', 'evelyn_russell', 'lawrence_gordon', 'irene_warren', 'bertha_kirkstein', 'mary_stewart', 'harry_knowles', 'drama', 'william_j._hanley', 'david_belasco', 'august_c._dorner'], tags=['la_belle_russe_tt0003672']),
#  TaggedDocument(words=['william_r._randall', 'robert_broderick', 'arthur_hoops', 'alice_claire_elliott', 'jack_henry', 'd._hogan', 'william_courtleigh_jr.', 'morgan_thorpe', 'drama', 'william_powers', 'cyrus_townsend_brady'], tags=['the_better_man_tt0003677']),
#  TaggedDocument(words=['bertel_krause', 'franz_skondrup', 'mathilde_felumb_friis', 'carl_schenstrøm', 'comedy', 'lau_lauritzen', 'edmund_pöhn'], tags=['det_blaa_vidunder_tt0003685']),
#  TaggedDocument(words=['joseph_singleton', 'edward_abeles', 'sydney_deane', 'miss_bartholomew', 'comedy', 'cecil_b._demille', 'oscar_apfel', 'byron_ongley', 'winchell_smith', 'george_barr_mccutcheon'], tags=["brewster's_millions_tt0003698"]),
#  TaggedDocument(words=['tom_mix', 'bessie_eyton', 'john_bowers', 'red_wing', 'wheeler_oakman', 'old_blue', 'western', 'francis_j._grandon', 'colin_campbell', 'gilson_willets'], tags=['in_the_days_of_the_thundering_herd_tt0003724']),
#  TaggedDocument(words=['claire_whitney', 'calvin_reisland', 'augusta_burmeister', 'edward_cecil', 'fraunie_fraunholz', 'james_j._corbett', 'crime', 'drama', 'herbert_blaché', 'langdon_mccormick'], tags=['the_burglar_and_the_lady_tt0003730']),
#  TaggedDocument(words=['mabel_kelly', 'edwina_robbins', 'jack_bulger', 'hughie_mack', 'william_r._dunn', 'harry_davenport', 'charles_brown', 'eulalie_jensen', 'comedy', 'tefft_johnson', 'frederick_chapin'], tags=['c.o.d._tt0003736']),
#  TaggedDocument(words=['carolina_catena', 'italia_almirante-manzini', 'bartolomeo_pagano', 'lidia_quaranta', 'adventure', 'drama', 'history', 'giovanni_pastrone', 'emilio_salgari', 'titus_livius', "gabriele_d'annunzio"], tags=['cabiria_tt0003740']),
#  TaggedDocument(words=['horace_b._carpenter', 'winifred_kingston', 'milton_brown', 'robert_edeson', 'florence_dagmar', 'theodore_roberts', 'adventure', 'drama', 'cecil_b._demille', 'oscar_apfel', 'stewart_edward_white', 'george_broadhurst'], tags=['the_call_of_the_north_tt0003743']),
#  TaggedDocument(words=['allan_forrest', 'ann_little', 'herbert_rawlinson', 'william_quinn', 'william_worthington', 'drama', 'otis_turner', 'james_dayton', 'hugh_conway'], tags=['called_back_tt0003744']),
#  TaggedDocument(words=['dustin_farnum', 'fred_montague', 'winifred_kingston', 'james_neill', 'jode_mullally', 'action', 'drama', 'romance', 'oscar_apfel', 'clara_beranger', 'harry_leon_wilson', 'booth_tarkington', 'william_c._de_mille'], tags=['cameo_kirby_tt0003747']),
#  TaggedDocument(words=['george_holt', 'otto_lederer', 'william_desmond_taylor', 'edith_storey', 'george_stanley', 'drama', 'rollin_s._sturgeon', 'marguerite_bertsch', 'h.s._sheldon', 'paul_gilmore'], tags=['captain_alvarez_tt0003748']),
#  TaggedDocument(words=["thomas_o'keefe", 'harry_spingler', 'frank_andrews', 'david_wall', 'iva_shepard', 'george_de_carlton', 'william_h._tooker', 'maxine_brown', 'drama', 'edgar_lewis', 'c._haddon_chambers'], tags=['captain_swift_tt0003752']),
#  TaggedDocument(words=['james_cruze', 'arthur_bauer', 'justus_d._barnes', 'j._morris_foster', 'florence_la_badie', 'lila_chester', 'nolan_gane', 'drama', 'eugene_moore', 'lloyd_lonergan', 'edward_george_bulwer-lytton'], tags=["cardinal_richelieu's_ward_tt0003756"]),
#  TaggedDocument(words=['guy_coombs', 'alice_joyce', 'marguerite_courtot', 'james_b._ross', 'harry_f._millarde', 'drama', 'george_melford', "adolphe_d'ennery", 'eugène_cormon', 'gene_gauntier'], tags=['a_celebrated_case_tt0003761']),
#  TaggedDocument(words=['jack_conway', 'joe_ray', 'myrtle_stedman', 'gordon_sackville', 'drama', 'hobart_bosworth', 'hettie_grey_baker', 'jack_london'], tags=['the_chechako_tt0003765']),
#  TaggedDocument(words=['milly_terriss', 'harry_hitchcock', 'alfred_hemming', 'vinnie_burns', 'faye_cusick', 'tom_terriss', 'robert_vivian', 'clarence_harvey', 'drama', 'fantasy', 'herbert_blaché', 'charles_dickens'], tags=['the_chimes_tt0003768']),
#  TaggedDocument(words=['harry_northrup', 'alberta_gallatin', 'donald_hall', 'jane_fearnley', 'carlotta_de_felice', 'edith_storey', 'drama', 'frederick_a._thomson', 'hall_caine', 'eugene_mullin'], tags=['the_christian_tt0003771']),
#  TaggedDocument(words=['lucille_carney', 'w.n._cone', 'georgia_wilson', 'isabel_vernon', 'hayward_mack', 'inez_ranous', 'mary_pickford', 'owen_moore', 'drama', 'fantasy', 'james_kirkwood', 'charles_perrault'], tags=['cinderella_tt0003772']),
#  TaggedDocument(words=['mabel_van_buren', 'howard_hickman', 'jode_mullally', 'florence_dagmar', 'hubert_whitehead', 'theodore_roberts', 'raymond_hatton', 'drama', 'oscar_apfel', 'cecil_b._demille', 'george_barr_mccutcheon'], tags=['the_circus_man_tt0003774']),
#  TaggedDocument(words=['edith_luckett', 'leonard_grover', 'lionel_adams', 'anna_rose', 'william_phillips', 'william_crimmins', 'theodore_kerwald', 'drama', 'edward_mackay', 'catherine_carr', 'raymond_c._hill'], tags=['the_coming_power_tt0003790']),
#  TaggedDocument(words=['iva_shepard', 'harold_lockwood', 'lois_meredith', 'john_emerson', 'drama', 'mystery', 'allan_dwan', 'robert_m._baker'], tags=['the_conspiracy_tt0003792']),
#  TaggedDocument(words=['daisy_jefferson', 'helen_aubrey', 'harold_lockwood', 'macklyn_arbuckle', 'mabel_wilbur', 'willis_p._sweatnam', 'william_lloyd', 'comedy', 'drama', 'allan_dwan', 'george_ade'], tags=['the_county_chairman_tt0003799']),
#  TaggedDocument(words=['blanche_fisher', 'justine_johnstone', 'lucy_parker', 'harold_lockwood', 'helen_hall', 'barbara_winthrop', 'marguerite_clark', 'drama', 'romance', 'hugh_ford', 'edwin_s._porter', 'mark_lee_luther'], tags=['the_crucible_tt0003804']),
#  TaggedDocument(words=['mrs._tom_ricketts', 'olive_templeton', 'jacqueline_moore', 'maud_milton', 'adrienne_morrison', 'richard_bennett', 'drama', 'tom_ricketts', 'harry_a._pollard', 'eugène_brieux'], tags=['damaged_goods_tt0003815']),
#  TaggedDocument(words=['cleo_madison', 'ann_little', 'herbert_rawlinson', 'william_worthington', 'drama', 'otis_turner', 'allan_dwan', 'james_dayton', 'edward_george_bulwer-lytton', 'ruth_ann_baldwin'], tags=['damon_and_pythias_tt0003816']),
#  TaggedDocument(words=['howard_lang', 'arthur_evans', 'cecil_spooner', 'victor_sutherland', 'marquita_dwight', 'drama', 'étienne_arnaud', 'edwin_carewe', 'j._searle_dawley'], tags=['the_dancer_and_the_king_tt0003820']),
#  TaggedDocument(words=['ethel_clayton', 'gaston_bell', 'mabel_greene', 'kempton_greene', 'robert_dunbar', 'lila_leslie', 'drama', 'george_terwilliger', 'charles_klein', 'lawrence_mccloskey'], tags=['the_daughters_of_men_tt0003825']),
#  TaggedDocument(words=['pearl_sindelar', 'jack_standing', 'francis_carlyle', 'ned_burton', 'charles_arling', 'crime', 'drama', 'donald_mackenzie', 'george_b._seitz'], tags=["detective_craig's_coup_tt0003830"]),
#  TaggedDocument(words=['russell_hicks', 'marion_weldon', 'si_jenks', 'al_bridge', 'charles_starrett', 'donald_grayson', 'adventure', 'music', 'western', 'charles_c._coleman', 'harold_shumate'], tags=['dodge_city_trail_tt0003854']),
#  TaggedDocument(words=['lindsay_j._hall', 'edward_roseman', 'stanley_walpole', 'robert_warwick', 'j.s._hale', 'barbara_tennant', 'eric_mayne', 'drama', 'o.a.c._lund', 'george_broadhurst'], tags=['the_dollar_mark_tt0003856']),
#  TaggedDocument(words=['christine_blessing', 'ernest_truex', 'william_h._tooker', 'gaston_mervale', 'laura_nelson_hall', 'drama', 'herman_lieb', 'joseph_medill_patterson'], tags=['dope_tt0003859']),
#  TaggedDocument(words=['john_ekman', 'jenny_tschernichin-larsson', 'nils_aréhn', 'nils_elffors', 'hilda_borgström', 'richard_lund', 'greta_almroth', 'drama', 'victor_sjöström', 'marius_wulff'], tags=['judge_not_tt0003870']),
#  TaggedDocument(words=['stanley_dark', 'george_irving', 'henry_driscole', 'digby_bell', 'kate_jepson', 'edna_mae_wilson', 'belle_daube', 'comedy', 'william_f._haddock', 'charles_dana_gibson', 'augustus_thomas'], tags=['the_education_of_mr._pipp_tt0003875']),
#  TaggedDocument(words=['gregory_scott', 'gerald_lawrence', 'douglas_payne', 'fay_davis', 'may_whitty', 'john_east', 'joan_ritz', 'ben_webster', 'drama', 'percy_nash', 'alfred_lord_tennyson'], tags=['enoch_arden_tt0003886']),
#  TaggedDocument(words=['blanche_sweet', 'donald_crisp', 'robert_harron', 'f.a._turner', 'drama', 'd.w._griffith', 'paul_armstrong'], tags=['the_escape_tt0003890']),
#  TaggedDocument(words=['raymond_owens', 'arnold_daly', 'pearl_white', 'creighton_hale', 'action', 'leopold_wharton', 'george_b._seitz', 'theodore_wharton', 'louis_j._gasnier', 'arthur_b._reeve', 'charles_w._goddard'], tags=['the_exploits_of_elaine_tt0003897']),
#  TaggedDocument(words=['george_schrode', 'william_t._carleton', 'william_fables', 'grace_goodall', 'richard_neill', 'edwin_clarke', 'marie_la_manna', 'billy_ruge', 'fantasy', 'charles_m._seay', 'george_hanlon_jr.'], tags=['fantasma_tt0003929']),
#  TaggedDocument(words=['rené_navarre', 'laurent_morléas', 'renée_carl', 'georges_melchior', 'crime', 'drama', 'louis_feuillade', 'pierre_souvestre', 'marcel_allain'], tags=['fantomas:_the_mysterious_finger_print_tt0003930']),
#  TaggedDocument(words=['l._rogers_lytton', 'templar_saxe', 'george_stevens', 'clara_kimball_young', 'charles_brown', 'comedy', 'wally_van', 'mark_swan', 'james_young'], tags=['the_fates_and_flora_fourflush_tt0003938']),
#  TaggedDocument(words=['mesnery', 'jean-françois_martial', 'edmund_breon', 'rené_navarre', 'laurent_morléas', 'georges_melchior', 'crime', 'drama', 'louis_feuillade', 'pierre_souvestre', 'marcel_allain'], tags=['fantômas:_the_false_magistrate_tt0003952']),
#  TaggedDocument(words=['albert_paulig', 'ressel_orla', 'victor_arnold', 'ernst_lubitsch', 'comedy', 'carl_wilhelm', 'walter_turszinsky', 'jacques_burg'], tags=['the_perfect_thirty-six_tt0003967']),
#  TaggedDocument(words=['ricca_allen', 'caroline_french', 'luke_j._loring', 'edwin_forsberg', 'hector_dion', 'frederick_burton', 'fritzi_brunette', 'drama', 'william_robert_daly', 'clay_m._greene', 'bennet_musson'], tags=['forgiven;_or,_the_jack_of_diamonds_tt0003987']),
#  TaggedDocument(words=['charles_brandt', 'ethel_clayton', 'george_soule_spencer', 'william_elliott', 'comedy', "barry_o'neil", 'clay_m._greene', 'winchell_smith'], tags=['the_fortune_hunter_tt0003988']),
#  TaggedDocument(words=['jane_gail', 'lewis_gilbert', 'gerald_ames', 'drama', 'war', 'george_loane_tucker', 'anne_merwin', 'bannister_merwin'], tags=['the_fringe_of_war_tt0003993']),
#  TaggedDocument(words=['james_cruze', 'phyllis_bostwick', 'harry_benham', 'helen_badgley', 'maude_fealy', 'drama', 'eugene_moore', 'lloyd_lonergan', 'augustin_daly', 'henri_meilhac', 'ludovic_halévy'], tags=['frou_frou_tt0003994']),
#  TaggedDocument(words=['ethel_clayton', 'gaston_bell', 'earl_metcalfe', 'kempton_greene', 'lila_leslie', 'gilbert_ely', 'drama', 'george_terwilliger', 'charles_klein'], tags=['the_gamblers_tt0004000']),
#  TaggedDocument(words=['stina_berg', 'sven_bergvall', 'john_ekman', 'gustaf_callmén', 'emil_bergendorff', 'lili_beck', 'drama', 'victor_sjöström', 'johanne_skram_knudsen', 'poul_knudsen'], tags=['gatans_barn_tt0004003']),
#  TaggedDocument(words=['louis_chrispijn_jr.', 'annie_bos', 'jan_van_dommelen', 'koba_kinsbergen', 'esther_de_boer-van_rijk', 'louis_bouwmeester', 'lau_ezerman', 'mientje_kling', 'drama', 'louis_h._chrispijn', 'otto_zeegers'], tags=['heilig_recht_tt0004004']),
#  TaggedDocument(words=['chester_barnett', 'evelyn_brent', 'thomas_a._wise', 'drama', 'george_l._sargent', 'harrison_garfield_rhodes'], tags=['a_gentleman_from_mississippi_tt0004006']),
#  TaggedDocument(words=['betty_johnson', 'rita_stanwood', 'theodore_roberts', 'h.b._warner', 'adventure', 'horror', 'cecil_b._demille', 'oscar_apfel', 'paul_dickey', 'james_montgomery', 'charles_w._goddard'], tags=['the_ghost_breaker_tt0004013']),
#  TaggedDocument(words=['antonio_nazzari', 'irene_mattalia', 'augusto_mastripietri', 'ignazio_lupi', 'bruto_castellani', 'gianna_terribili-gonzales', 'amleto_novelli', 'drama', 'history', 'enrico_guazzoni', 'william_shakespeare', 'raffaele_giovagnoli'], tags=['julius_caesar_tt0004022']),
#  TaggedDocument(words=['ernest_truex', 'william_norris', 'iva_merlin', 'mary_pickford', 'drama', 'edwin_s._porter', 'j._searle_dawley', 'maurice_rostand', 'rosemonde_gerard', 'austin_strong'], tags=['a_good_little_devil_tt0004027']),
#  TaggedDocument(words=['elita_proctor_otis', 'martin_alsop', 'wallace_eddinger', 'charles_j._ross', 'purnell_pratt', 'gail_kane', 'drama', 'edward_a._morange', 'edward_m._alfriend', 'a.c._wheeler', 'herbert_hall_winslow'], tags=['the_great_diamond_robbery_tt0004037']),
#  TaggedDocument(words=['robert_harron', 'raoul_walsh', 'ralph_lewis', 'irene_hunt', 'donald_crisp', 'eagle_eye', 'mae_marsh', 'drama', 'romance', 'christy_cabanne', 'anthony_paul_kelly'], tags=['the_great_leap:_until_death_do_us_part_tt0004038']),
#  TaggedDocument(words=['elita_proctor_otis', 'catherine_carter', 'harry_spingler', 'david_wall', 'george_de_carlton', 'william_h._tooker', 'crime', 'drama', 'lawrence_b._mcgill', 'wilson_mizner', 'louis_reeves_harrison', 'paul_armstrong'], tags=['the_greyhound_tt0004043']),
#  TaggedDocument(words=['john_ekman', 'gunnar_tolnæs', 'erik_lindholm', 'karin_molander', 'georg_grönroos', 'greta_pfeil', 'william_larsson', 'drama', 'victor_sjöström', 'peter_lykke-seest'], tags=['half_breed_tt0004047']),
#  TaggedDocument(words=['hamilton_revelle', 'drama', 'arturo_ambrosio', 'william_shakespeare'], tags=['hamlet_tt0004049']),
#  TaggedDocument(words=['j.p._mcgowan', 'helen_holmes', 'helen_gibson', 'ethel_clisbee', 'action', 'j._gunnis_davis', 'leo_d._maloney', 'robert_g._vignola', 'paul_hurst', 'frank_howard_clark', 'john_russell_corvell'], tags=['the_hazards_of_helen_tt0004052']),
#  TaggedDocument(words=['del_de_lewis', 'wilbur_hudson', 'frederick_roland', 'd.h._turner', 'george_w._middleton', 'ralph_stewart', 'james_a._fitzgerald', 'violet_horner', 'drama', 'wray_bartlett_physioc', 'james_a._herne'], tags=['hearts_of_oak_tt0004063']),
#  TaggedDocument(words=['a.v._bramble', 'fred_groves', 'm._gray_murray', 'elisabeth_risdon', 'crime', 'drama', 'maurice_elvey', 'eliot_stannard', 'charles_darrell'], tags=['her_luck_in_london_tt0004078']),
#  TaggedDocument(words=['pierre_couderc', 'fred_woodward', 'violet_macmillan', 'frank_moore', 'adventure', 'comedy', 'family', 'j._farrell_macdonald', 'l._frank_baum'], tags=['the_new_wizard_of_oz_tt0004099']),
#  TaggedDocument(words=['erwin_fichtner', 'hanni_weisse', 'alwin_neuß', 'friedrich_kühne', 'crime', 'horror', 'mystery', 'rudolf_meinert', 'julius_philipp', 'arthur_conan_doyle', 'richard_oswald'], tags=['der_hund_von_baskerville_tt0004121']),
#  TaggedDocument(words=['edwin_barbour', 'ethel_clayton', 'gaston_bell', 'florence_williams', 'george_soule_spencer', 'mrs._george_w._walters', 'drama', "barry_o'neil", 'clay_m._greene', 'j._hartley_manners'], tags=['the_house_next_door_tt0004125']),
#  TaggedDocument(words=['susanne_willis', 'robert_lawrence', 'lottie_pickford', 'armand_cortes', 'drama', 'pierce_kingsley', 'raymond_b._west', 'j.g._hawks', 'reginald_wright_kauffman'], tags=['the_house_of_bondage_tt0004126']),
#  TaggedDocument(words=['philippa_frederiksen', 'birger_von_cotta-schønberg', 'christel_holch', 'carl_lauritzen', 'carl_schenstrøm', 'ingeborg_jensen', 'comedy', 'sofus_wolder', 'aage_i.c._schmidt'], tags=['i_kammerherrens_klæder_tt0004136']),
#  TaggedDocument(words=['constance_walton', 'gordon_dennis', 'a.v._bramble', 'fred_groves', 'elisabeth_risdon', 'crime', 'drama', 'maurice_elvey', 'eliot_stannard', 'charles_darrell'], tags=['the_idol_of_paris_tt0004138']),
#  TaggedDocument(words=['william_garwood', 'drama', "john_b._o'brien", 'daniel_carson_goodman'], tags=['imar_the_servitor_tt0004142']),
#  TaggedDocument(words=['jesse_m._lee', 'nelson_appleton_miles', 'frank_d._baldwin', 'history', 'western', 'theodore_wharton', 'vernon_day', 'charles_king'], tags=['the_indian_wars_tt0004155']),
#  TaggedDocument(words=['viola_allen_frayne', 'alan_hale', 'harrish_ingraham', 'lisbeth_blackstone', 'alberta_roy', 'mary_fry_clements', 'dallas_tyler', 'john_charles', 'drama', 'martin_faust', 'charlotte_brontë'], tags=['jane_eyre_tt0004167']),
#  TaggedDocument(words=['elmo_lincoln', 'antrim_short', 'elmer_clifton', 'matty_roubert', 'joe_ray', 'viola_barry', 'drama', 'j._charles_haydon', 'hobart_bosworth', 'hettie_grey_baker', 'jack_london'], tags=['john_barleycorn_tt0004175']),
#  TaggedDocument(words=['james_cruze', 'arthur_bauer', 'justus_d._barnes', 'john_lehnberg', 'lila_chester', 'marguerite_snow', 'drama', 'eugene_moore', 'lloyd_lonergan', 'theodore_a._liebler_jr.'], tags=['joseph_in_the_land_of_egypt_tt0004179']),
#  TaggedDocument(words=['blanche_sweet', 'henry_b._walthall', 'robert_harron', 'mae_marsh', 'drama', 'd.w._griffith', 'frank_e._woods', 'thomas_bailey_aldrich', 'grace_pierce'], tags=['judith_of_bethulia_tt0004181']),
#  TaggedDocument(words=['robert_cummings', 'george_nash', 'julia_hurley', 'gail_kane', 'drama', 'jack_pratt', 'george_irving', 'augustus_thomas', 'upton_sinclair', 'margaret_mayo', 'benjamin_s._kutler'], tags=['the_jungle_tt0004182']),
#  TaggedDocument(words=['edna_mayo', 'john_sheehan', 'george_brunton', 'carlyle_blackwell', 'gypsy_abbott', 'jack_prescott', 'drama', 'john_francis_dillon', 'charles_neville_buck', 'robert_dillon'], tags=['the_key_to_yesterday_tt0004188']),
#  TaggedDocument(words=['lili_berky', 'kató_berky', 'marcsa_simon', 'elza_báthory', 'aladár_ihász', 'alajos_mészáros', 'comedy', 'michael_curtiz', 'margaret_mayo', 'jenö_janovics'], tags=['the_borrowed_babies_tt0004199']),
#  TaggedDocument(words=['albert_roccardi', 'mandy_wilson', 'karin_norman', 'jane_fearnley', 'antonio_moreno', 'cissy_fitzgerald', 'comedy', 'wilfrid_north', 'roy_l._mccardell'], tags=["the_ladies'_war_tt0004201"]),
#  TaggedDocument(words=['irene_hunt', 'robert_harron', 'w.h._lawrence', 'eagle_eye', 'action', 'adventure', 'biography', 'christy_cabanne', 'raoul_walsh', 'frank_e._woods'], tags=['the_life_of_general_villa_tt0004223']),
#  TaggedDocument(words=['teresa_michelena', 'walter_hitchcock', 'claire_whitney', 'stuart_holmes', 'drama', 'j._gordon_edwards', 'mary_asquith', 'victoria_cross'], tags=["life's_shop_window_tt0004224"]),
#  TaggedDocument(words=['ethel_clayton', 'george_soule_spencer', 'gaston_bell', 'bartley_mccullum', 'drama', "barry_o'neil", 'charles_klein'], tags=['the_lion_and_the_mouse_tt0004232']),
#  TaggedDocument(words=['george_holt', 'otto_lederer', 'william_v._ranous', 'george_streaton', 'gertrude_short', 'george_stanley', 'western', 'rollin_s._sturgeon', 'jasper_ewing_brady', 'cyrus_townsend_brady'], tags=['the_little_angel_of_canyon_creek_tt0004234']),
#  TaggedDocument(words=['james_cooley', 'edgar_l._davenport', 'julia_walcott', 'jane_fearnley', 'mathaleen_aamold', 'robert_cummings', 'hal_clarendon', 'jane_grey', 'drama', 'francis_powers', 'channing_pollock'], tags=['the_little_gray_lady_tt0004236']),
#  TaggedDocument(words=['gerald_royston', 'bernard_vaughan', 'h._agar_lyons', 'frank_stather', 'jane_wells', 'd._callam', 'v._osmond', 'harry_edwards', 'drama', 'f._martin_thornton', 'frances_hodgson_burnett'], tags=['little_lord_fauntleroy_tt0004238']),
#  TaggedDocument(words=['fred_fleck', 'e.k._lincoln', 'estelle_mardo', 'elaine_ivans', 'martin_reagan', 'mimi_yvonne', 'william_sorelle', 'drama', 'edgar_lewis', 'edward_peple'], tags=['the_littlest_rebel_tt0004244']),
#  TaggedDocument(words=['catherine_carter', 'arthur_hoops', 'mark_price', 'rita_stan', 'h.b._warner', 'drama', 'j._searle_dawley', 'henry_c._demille', 'ludwig_fulda'], tags=['the_lost_paradise_tt0004257']),
#  TaggedDocument(words=['maurice_l._kusell', 'arthur_hoyt', 'ruth_stonehouse', 'mattie_witting', 'franklyn_farnum', 'kingsley_benedict', 'dorothy_clark', 'drama', 'william_worthington', 'harvey_gates'], tags=['love_never_dies_tt0004267']),
#  TaggedDocument(words=['claire_whitney', 'lucia_moore', 'bernard_daly', 'lola_may', 'fraunie_fraunholz', 'kirah_markham', 'wallace_scott', "james_o'neill", 'drama', 'alice_guy', 'george_scarborough'], tags=['the_lure_tt0004275']),
#  TaggedDocument(words=['charles_ogle', 'marjorie_ellison', 'harry_b._eytinge', 'marc_mcdermott', 'miriam_nesbitt', "barry_o'moore", 'cora_williams', 'harry_mason', 'thriller', 'charles_brabin', 'richard_washburn_child'], tags=['the_man_who_disappeared_tt0004292']),
#  TaggedDocument(words=['fred_montague', 'charles_richman', 'theodore_roberts', 'monroe_salisbury', 'drama', 'cecil_b._demille', 'harry_leon_wilson', 'booth_tarkington'], tags=['the_man_from_home_tt0004294']),
#  TaggedDocument(words=['fred_annerly', 'winona_winter', 'john_barrymore', 'wellington_a._playter', 'harold_lockwood', 'anton_van_leer_ascher', 'pauline_neff', 'comedy', 'thomas_n._heffron', 'eve_unsell', 'h.a._dusouchet'], tags=['the_man_from_mexico_tt0004295']),
#  TaggedDocument(words=['alec_b._francis', 'thomas_jackson', 'robert_warwick', 'johnny_hines', 'belle_adair', 'chester_barnett', 'eric_mayne', 'ned_burton', 'drama', 'maurice_tourneur', 'george_broadhurst'], tags=['man_of_the_hour_tt0004301']),
#  TaggedDocument(words=['fred_montague', 'betty_johnson', 'fred_l._wilson', 'harry_fisher', 'mabel_van_buren', 'max_figman', 'c.f._le_none', 'comedy', 'drama', 'cecil_b._demille', 'oscar_apfel', 'harold_mcgrath'], tags=['the_man_on_the_box_tt0004302']),
#  TaggedDocument(words=['henry_weaver', 'lina_cavalieri', 'lucien_muratore', 'william_l._abingdon', 'dorothy_arthur', 'frank_h._westerton', 'charles_hammond', 'drama', 'romance', 'herbert_hall_winslow', 'abbé_prévost'], tags=['manon_lescaut_tt0004303']),
#  TaggedDocument(words=['lillian_kalich', 'george_moss', 'bertha_kalich', 'wellington_a._playter', 'frank_holland', 'hal_clarendon', 'drama', 'j._searle_dawley', 'àngel_guimerà'], tags=['marta_of_the_lowlands_tt0004306']),
#  TaggedDocument(words=['rhea_haines', 'elmer_clifton', 'ray_myers', 'lawrence_peyton', 'herbert_rawlinson', 'ann_ivers', 'viola_barry', 'drama', 'hobart_bosworth', 'jack_london'], tags=['martin_eden_tt0004307']),
#  TaggedDocument(words=['fred_montague', 'harry_fisher', 'edmund_breese', 'mabel_van_buren', 'dick_la_reno', 'jane_darwell', 'crime', 'drama', 'cecil_b._demille', 'oscar_apfel', 'clara_beranger', 'david_daniel_cohen'], tags=['the_master_mind_tt0004314']),
#  TaggedDocument(words=['eugenie_besserer', 'harold_lockwood', 'stella_razeto', 'lillian_hayward', 'guy_oliver', 'lea_errol', 'al_w._filson', 'drama', 'romance', 'edward_lesaint', 'gladys_p._pullen'], tags=['memories_tt0004321']),
#  TaggedDocument(words=['daniel_makarenko', 'ormi_hawley', 'peter_lang', 'jacob_p._adler', 'eleanor_barry', 'betty_brice', 'drama', 'lloyd_b._carleton', 'jules_verne', 'benjamin_s._kutler'], tags=['michael_strogoff_tt0004328']),
#  TaggedDocument(words=['gladden_james', 'charles_kent', 'e.k._lincoln', 'anita_stewart', 'harry_t._morey', 'julia_swayne_gordon', 'drama', 'romance', 'ralph_ince', 'marguerite_bertsch', 'mrs._sidney_drew'], tags=['a_million_bid_tt0004335']),
#  TaggedDocument(words=['james_cruze', 'florence_la_badie', 'frank_farrington', 'marguerite_snow', 'sidney_bracey', 'adventure', 'mystery', 'howell_hansel', 'lloyd_lonergan', 'harold_mcgrath'], tags=['the_million_dollar_mystery_tt0004336']),
#  TaggedDocument(words=['edna_mayo', 'robert_stowe_gill', 'ruby_hoffman', 'william_roselle', 'john_daly_murphy', 'edward_abeles', 'comedy', 'drama', 'thomas_n._heffron', 'eve_unsell', 'marcel_guillemaud', 'georges_berr'], tags=['the_million_tt0004338']),
#  TaggedDocument(words=['mary_charleson', 'adele_degarde', 'charles_kent', 'maurice_costello', 'william_humphrey', 'naomi_childers', 'darwin_karr', 'drama', 'robert_gaillard', 'archibald_clavering_gunter', 'eugene_mullin'], tags=['mr._barnes_of_new_york_tt0004362']),
#  TaggedDocument(words=['james_hester', 'charles_lane', 'elmer_booth', 'wellington_a._playter', 'clara_blandick', 'may_irwin', 'cyril_chadwick', 'comedy', 'thomas_n._heffron', 'eve_unsell', 'george_v._hobart'], tags=['mrs._black_is_back_tt0004363']),
#  TaggedDocument(words=['house_peters', 'beatriz_michelena', 'la_belle_carmen', 'blanche_chapman', 'andrew_robson', 'drama', 'harold_entwistle', 'anne_crawford_flexner', 'alice_hegan_rice'], tags=['mrs._wiggs_of_the_cabbage_patch_tt0004365']),
#  TaggedDocument(words=['l._rogers_lytton', 'rose_tapley', 'clara_kimball_young', 'harry_t._morey', 'mary_anderson', 'earle_williams', 'drama', 'james_young', 'marguerite_bertsch', 'richard_henry_savage'], tags=['my_official_wife_tt0004369']),
# ...
#  TaggedDocument(words=['ralph_lewis', 'eugene_pallette', "james_o'shea", 'clyde_e._hopkins', 'wilfred_lucas', 'bessie_love', 'mary_alden', 'comedy', 'drama', 'paul_powell', "mary_h._o'connor"], tags=['hell-to-pay_austin_tt0006781']),
#  TaggedDocument(words=['arthur_donaldson', 'ormi_hawley', 'john_webb_dillion', 'ruby_hoffman', 'j._frank_glendon', 'bradley_barker', 'drama', 'd.h._turner', 'carl_herbert'], tags=['her_american_prince_tt0006784']),
#  TaggedDocument(words=['cleo_madison', 'edward_hearn', 'ray_hanford', 'margaret_whistler', 'lule_warrenton', 'william_v._mong', 'adele_farrington', 'willis_marks', 'drama', 'joe_king', 'kathleen_kerrigan'], tags=['her_bitter_cup_tt0006785']),
#  TaggedDocument(words=['theda_bara', 'stuart_holmes', 'walter_law', 'madeleine_le_nard', 'franklyn_hanna', 'carey_lee', 'jane_lee', 'drama', 'j._gordon_edwards', 'mary_murillo'], tags=['her_double_life_tt0006788']),
#  TaggedDocument(words=['helen_jerome_eddy', 'joe_massey', 'gayne_whitman', 'vivian_martin', 'herbert_standing', 'comedy', 'william_desmond_taylor', 'anna_fielder_brand', 'l.v._jefferson'], tags=["her_father's_son_tt0006789"]),
#  TaggedDocument(words=['lillian_concord', 'eileen_sedgwick', 'william_quinn', 'roberta_wilson', 'alfred_wertz', 'drama', 'burton_george', 'arthur_shirley', 'walter_woods', 'elliott_j._clawson'], tags=['the_heritage_of_hate_tt0006795']),
#  TaggedDocument(words=['ethel_clayton', 'montagu_love', 'edward_kimball', 'madge_evans', 'irving_cummings', 'holbrook_blinn', 'drama', "barry_o'neil", 'mrs._owen_bronson', 'frances_marion'], tags=['the_hidden_scar_tt0006798']),
#  TaggedDocument(words=['helena_rupport', 'clarence_handyside', 'loretta_blake', 'jean_temple', 'douglas_fairbanks', 'charles_butler', 'homer_hunt', 'rene_boucicault', 'comedy', 'john_emerson', 'anita_loos'], tags=['his_picture_in_the_papers_tt0006809']),
#  TaggedDocument(words=['wilfred_lytell', 'john_s._robertson', 'lucille_lee_stewart', 'jessie_miller', 'frank_currier', 'huntley_gordon', 'drama', 'ralph_ince', 'edward_j._montagne', 'josephine_lovett'], tags=["his_wife's_good_name_tt0006812"]),
#  TaggedDocument(words=['max_ruhbeck', 'kurt_wolowsky', 'paula_ronay', 'erich_kaiser-titz', 'fantasy', 'richard_oswald', 'fritz_friedmann-frederich', 'e.t.a._hoffmann'], tags=['hoffmanns_erzählungen_tt0006819']),
#  TaggedDocument(words=['ernst_ludwig', 'adolf_paul', 'albert_paul', 'olaf_fønss', 'lore_rückert', 'horror', 'sci-fi', 'otto_rippert', 'robert_reinert'], tags=['homunculus,_1._teil_tt0006820']),
#  TaggedDocument(words=['george_fisher', 'frank_keenan', 'harvey_clark', 'charles_ray', 'louise_glaum', 'gertrude_claire', 'drama', 'charles_giblyn', 'j.g._hawks'], tags=['honor_thy_name_tt0006822']),
#  TaggedDocument(words=['sidney_mason', 'caroline_harris', 'yolande_duquette', 'violet_mersereau', "james_o'neill", 'tina_marshall', 'drama', 'edwin_stevens', 'john_c._brownell'], tags=['the_honor_of_mary_blake_tt0006823']),
#  TaggedDocument(words=['m._matsumato', 'tsuru_aoki', 'sessue_hayakawa', 'goro_kino', 'william_elmer', 'raymond_hatton', 'drama', 'edward_lesaint', 'eve_unsell', 'elizabeth_mcgaffey'], tags=['the_honorable_friend_tt0006825']),
#  TaggedDocument(words=['robert_harron', "loyola_o'connor", 'mildred_harris', 'wilbur_higby', 'pearl_elmore', 'william_h._brown', 'mae_marsh', 'comedy', 'drama', 'romance', 'lloyd_ingraham', 'd.w._griffith'], tags=['hoodoo_ann_tt0006826']),
#  TaggedDocument(words=['mabel_van_buren', 'billy_jacobs', 'james_neill', 'wallace_reid', 'marjorie_daw', 'cleo_ridgely', 'drama', 'george_melford', 'charles_sarver', 'l.v._jefferson'], tags=['the_house_with_the_golden_windows_tt0006828']),
#  TaggedDocument(words=['harold_holland', 'edna_goodrich', 'kathleen_kirkham', 'herbert_standing', 'juan_de_la_cruz', 'lucille_ward', 'drama', 'william_desmond_taylor', 'l.v._jefferson'], tags=['the_house_of_lies_tt0006830']),
#  TaggedDocument(words=['mary_pickford', 'frank_losee', 'russell_bassett', 'john_bowers', 'charles_e._vernon', 'harold_hollacher', 'cesare_gravina', 'drama', "john_b._o'brien", 'edith_barnard_delano'], tags=['hulda_from_holland_tt0006831']),
#  TaggedDocument(words=['alec_b._francis', 'leonore_harris', 'al_hart', 'robert_warwick', 'frances_nelson', 'drama', 'emile_chautard', 'emmett_c._hall'], tags=['human_driftwood_tt0006833']),
#  TaggedDocument(words=['joseph_w._girard', 'mary_fuller', 'sidney_bracey', 'drama', 'lucius_henderson', 'catherine_carr', 'g._vere_tyler'], tags=['the_huntress_of_men_tt0006837']),
#  TaggedDocument(words=['ethel_clayton', 'montagu_love', 'madge_evans', 'emmett_corrigan', 'holbrook_blinn', 'dion_titheradge', 'drama', "barry_o'neil", 'charles_kenyon', 'gardner_hunting'], tags=['husband_and_wife_tt0006838']),
#  TaggedDocument(words=['henry_leone', 'adella_barker', 'lydia_dickson', 'john_webb_dillion', 'alfred_swenson', 'gladys_morris', 'ida_darling', 'virginia_pearson', 'drama', 'kenean_buel', 'hugh_c._weir'], tags=['hypocrisy_tt0006840']),
#  TaggedDocument(words=['albert_macquarrie', 'frank_whitson', 'lon_chaney', 'helen_leslie', 'jack_nelson', 'dorothy_phillips', 'drama', 'joseph_de_grasse', 'ida_may_park', 'virginia_terhune_vandewater'], tags=['if_my_country_should_call_tt0006847']),
#  TaggedDocument(words=['winifred_greenwood', 'franklin_ritchie', 'roy_stewart', 'drama', 'edward_sloman', 'julian_la_mothe'], tags=['the_inner_struggle_tt0006858']),
#  TaggedDocument(words=['viola_dana', 'brad_sutton', 'edward_earle', 'nellie_grant', 'augustus_phillips', 't._tamamoto', 'robert_brower', 'lena_davril', 'drama', 'john_h._collins', 'william_addison_lathrop'], tags=['the_innocence_of_ruth_tt0006859']),
#  TaggedDocument(words=['robert_cain', 'hunter_arden', 'j._morris_foster', 'valentine_grant', 'j.j._clark', 'helen_lindroth', 'drama', 'sidney_olcott', 'hugh_ford', 'lois_zellner'], tags=['the_innocent_lie_tt0006860']),
#  TaggedDocument(words=['seymour_hastings', 'jennie_lee', 'spottiswoode_aitken', 'sam_de_grasse', 'mary_alden', 'lillian_gish', 'drama', 'allan_dwan', 'd.w._griffith', 'roy_somerville'], tags=['an_innocent_magdalene_tt0006861']),
#  TaggedDocument(words=['grace_carlyle', 'olive_white', 'rita_jolivet', 'marc_b._robbins', 'courtenay_foote', 'elliott_dexter', 'page_peters', 'comedy', 'drama', 'frank_lloyd', 'george_broadhurst'], tags=['an_international_marriage_tt0006862']),
#  TaggedDocument(words=['harry_lonsdale', 'kathlyn_williams', 'guy_oliver', 'adventure', 'drama', 'thomas_n._heffron', 'robert_ames_bennet'], tags=['into_the_primitive_tt0006863']),
#  TaggedDocument(words=['f.a._turner', 'robert_harron', 'lillian_gish', 'mae_marsh', 'drama', 'history', 'd.w._griffith', 'walt_whitman', "mary_h._o'connor", 'anita_loos', 'tod_browning', 'hettie_grey_baker'], tags=["intolerance:_love's_struggle_throughout_the_ages_tt0006864"]),
#  TaggedDocument(words=['howard_davies', 'lenore_ulric', 'paul_weigel', 'cecil_van_auker', 'king_vidor', 'florence_vidor', 'herbert_standing', 'drama', 'frank_lloyd', 'julia_crawford_ivers'], tags=['the_intrigue_tt0006865']),
#  TaggedDocument(words=['violet_hopson', 'alma_taylor', 'henry_ainley', 'stewart_rome', 'drama', 'romance', 'cecil_m._hepworth', 'arthur_wing_pinero'], tags=['iris_tt0006866']),
#  TaggedDocument(words=['hobart_bosworth', 'winifred_harris', 'frank_newburg', 'jack_curtis', 'william_v._mong', 'maude_george', 'edward_clark', 'drama', 'ulysses_davis', 'george_edwardes-hall', 'f._mcgrew_willis'], tags=['the_iron_hand_tt0006868']),
#  TaggedDocument(words=['alfred_hickman', 'einar_linden', "nance_o'neil", 'vera_sisson', 'william_postance', 'evelyn_brent', 'drama', 'carl_harbaugh', 'margaret_deland', 'wallace_clifton'], tags=['the_iron_woman_tt0006870']),
#  TaggedDocument(words=['william_courtenay', 'charles_kent', 'denton_vane', 'eleanor_woodruff', 'anders_randolf', 'charles_wellesley', 'drama', 'paul_scardon', 'jasper_ewing_brady', 'cyrus_townsend_brady'], tags=['the_island_of_surprise_tt0006873']),
#  TaggedDocument(words=['frank_whitson', 'hayward_mack', 'lillian_concord', 'hector_v._sarno', 'roberta_wilson', 't.d._crittenden', 'adventure', 'romance', 'burton_george', 'stephen_french_whitman', 'fred_myton'], tags=['the_isle_of_life_tt0006874']),
#  TaggedDocument(words=['enid_markey', 'fanny_midgley', 'frank_keenan', 'j.p._lockney', 'robert_mckim', 'western', 'reginald_barker', 'lanier_bartlett'], tags=["jim_grimsby's_boy_tt0006881"]),
#  TaggedDocument(words=['tyrone_power_sr.', 'agnes_emerson', 'frank_elliott', 'walter_belasco', 'drama', 'lois_weber', 'phillips_smalley', 'olga_printzlau', 'joseph_hatton'], tags=["john_needham's_double_tt0006883"]),
#  TaggedDocument(words=['musidora', 'édouard_mathé', 'rené_cresté', 'rené_poyen', 'adventure', 'crime', 'louis_feuillade', 'arthur_bernède'], tags=['judex_tt0006886']),
#  TaggedDocument(words=['thomas_g._lingham', 'clara_mosher', 'leo_d._maloney', 'paul_hurst', 'harold_warner_lloyd', 'helen_holmes', 'william_brunton', 'drama', 'j.p._mcgowan', 'alice_macgowan'], tags=['judith_of_the_cumberlands_tt0006889']),
#  TaggedDocument(words=['alfréd_deésy', 'annie_góth', 'alajos_turányi', 'lilla_bársony', 'drama', 'michael_curtiz', 'tibor_rákosi', 'józsef_eötvös', 'peter_paul_felner'], tags=['the_karthauzer_tt0006893']),
#  TaggedDocument(words=['daniel_jarrett', 'muriel_ostriche', 'raymond_bloomer', 'charles_kent', 'antonio_moreno', 'hattie_delaro', 'tom_brooke', 'drama', 'history', 's._rankin_drew', 'f._hopkinson_smith'], tags=['kennedy_square_tt0006894']),
#  TaggedDocument(words=['wayne_arey', 'j.h._gilmour', 'lorraine_huling', 'frederick_warde', 'drama', 'ernest_c._warde', 'philip_lonergan', 'william_shakespeare'], tags=['king_lear_tt0006895']),
#  TaggedDocument(words=["edward_o'neill", 'hayford_hobbs', 'janet_ross', 'gerald_ames', 'hubert_willis', 'drama', 'maurice_elvey', 'alexandre_dumas'], tags=["the_king's_daughter_tt0006896"]),
#  TaggedDocument(words=['george_parks', 'pearl_white', 'george_probert', 'sheldon_lewis', 'nora_moore', 'comedy', 'drama', 'ashley_miller', 'george_b._seitz'], tags=["the_king's_game_tt0006897"]),
#  TaggedDocument(words=['ruth_stonehouse', 'r.a._cavin', 'harry_griffith', 'raymond_whitaker', 'noble_johnson', 'harry_mann', 'j.h._knowles', 'crime', 'drama', 'raymond_wells', 'fred_myton'], tags=['kinkaid,_gambler_tt0006898']),
#  TaggedDocument(words=['victor_de_linsky', 'niles_welch', 'robert_elliott', 'ethel_barrymore', 'william_l._abingdon', 'h._cooper_cliffe', 'roy_applegate', 'drama', 'william_nigh', 'frédérique_de_grésac'], tags=['the_kiss_of_hate_tt0006899']),
#  TaggedDocument(words=["thomas_o'keefe", 'adolphe_menjou', 'marguerite_courtot', 'virginia_hammond', 'owen_moore', 'kate_lester', 'comedy', 'drama', 'dell_henderson', 'elizabeth_frazer', 'harvey_f._thew'], tags=['the_kiss_tt0006900']),
#  TaggedDocument(words=['jane_wolfe', 'veda_mcevers', 'james_neill', 'thomas_delmar', 'elliott_dexter', 'marie_doro', 'drama', 'james_young', 'george_dubois_proctor', 'paul_west'], tags=['the_lash_tt0006908']),
#  TaggedDocument(words=['helen_holmes', 'leo_d._maloney', 'thomas_g._lingham', 'william_n._chapman', 'western', 'j.p._mcgowan', 'paul_hurst', 'ford_beebe', 'e._alexander_powell'], tags=['a_lass_of_the_lumberlands_tt0006909']),
#  TaggedDocument(words=['jack_mower', 'otto_lederer', 'corinne_griffith', 'william_duncan', 'hans_unterkircher', 'mary_anderson', 'drama', 'romance', 'war', 'william_wolbert', 'james_oliver_curwood'], tags=['the_last_man_tt0006910']),
#  TaggedDocument(words=['david_powell', 'mario_majeroni', 'frank_losee', 'cesare_gravina', 'mary_pickford', 'mary_alden', 'drama', 'john_emerson', 'hector_turnbull'], tags=['less_than_the_dust_tt0006914']),
#  TaggedDocument(words=['jack_holt', 'eddie_polo', 'marie_walcamp', 'g._raymond_nye', 'action', 'adventure', 'war', 'jacques_jaccard', 'henry_macrae', 'w.b._pearson'], tags=['liberty_tt0006917']),
#  TaggedDocument(words=['hedda_kuszewski', 'orrin_johnson', 'sally_crute', 'mary_carr', 'evelyn_terrill', 'robert_frazer', 'drama', 'edgar_lewis', 'anthony_paul_kelly'], tags=['the_light_at_dusk_tt0006922']),
#  TaggedDocument(words=['ella_hall', 'thomas_jefferson', 'gretchen_lederer', 'herbert_rawlinson', 'doris_pawn', 'mark_fenton', 'comedy', 'drama', 'robert_z._leonard', 'eleanor_hallowell_abbott'], tags=['little_eve_edgarton_tt0006928']),
#  TaggedDocument(words=['maggie_fisher', 'vernon_steele', 'john_l._shine', 'j.k._murray', 'harry_lee', 'marguerite_clark', 'romance', 'j._searle_dawley', 'hugh_ford', 'betty_t._fitzgerald'], tags=['little_lady_eileen_tt0006930']),
#  TaggedDocument(words=['robert_harron', "loyola_o'connor", 'tom_wilson', 'ruth_handforth', 'olga_grey', 'jennie_lee', 'carl_stockdale', 'mae_marsh', 'drama', 'lloyd_ingraham', 'anita_loos'], tags=['the_little_liar_tt0006931']),
#  TaggedDocument(words=['george_c._pearce', 'mazie_radford', 'dorothy_gish', 'robert_lawler', 'alberta_lee', 'fred_j._butler', 'owen_moore', 'comedy', 'drama', 'paul_powell', 'f.m._pierson'], tags=["little_meena's_romance_tt0006933"]),
#  TaggedDocument(words=['sara_alexander', 'leo_a._kennedy', 'june_caprice', 'harry_hilliard', 'robert_vivian', 'zena_keefe', 'sidney_bracey', 'drama', 'john_g._adolfi', 'clarence_j._harris'], tags=['little_miss_happiness_tt0006934']),
#  TaggedDocument(words=['mildred_gregory', 'joseph_daly', 'mathilde_brundage', 'marguerite_skirvin', 'joseph_w._girard', 'william_welsh', 'cyril_scott', 'drama', 'jack_harvey', 'meredith_m._nicholson', 'william_h._lippert'], tags=['the_lords_of_high_decision_tt0006941']),
#  TaggedDocument(words=['john_t._dillon', 'june_dale', 'hardee_kirkland', 'john_barrymore', 'ida_darling', 'katherine_corri_harris', 'eddie_sturgis', 'comedy', 'james_kirkwood', 'willard_mack'], tags=['the_lost_bridegroom_tt0006942']),
#  TaggedDocument(words=['oliver_hardy', 'thurlow_bergen', 'elsie_esmond', 'allan_murnane', 'comedy', 'leopold_wharton', 'theodore_wharton', 'rida_johnson_young'], tags=['the_lottery_man_tt0006943']),
#  TaggedDocument(words=['dorothy_abril', 'earle_foxe', 'bob_fleming', 'wallace_reid', 'cleo_ridgely', 'drama', 'romance', 'western', 'frank_reicher', 'jeanie_macpherson', 'cecil_b._demille'], tags=['the_love_mask_tt0006947']),
#  TaggedDocument(words=['frances_burnham', 'alan_hale', 'edward_cecil', 'jack_mcdonald', 'willard_louis', 'gretchen_hartman', 'drama', 'richard_stanton', 'm.p._niessen', 'bennett_cohen'], tags=['the_love_thief_tt0006950']),
#  TaggedDocument(words=['madeleine_le_nard', 'bertha_kalich', 'kenneth_hunter', 'stuart_holmes', 'jane_lee', 'drama', 'james_vincent', 'james_r._garey', 'mary_murillo'], tags=['love_and_hate_tt0006953']),
#  TaggedDocument(words=['harry_carey', 'olive_carey', 'william_quinn', 'neal_hart', 'comedy', 'western', 'george_marshall', 'w.b._pearson'], tags=["love's_lariat_tt0006956"]),
#  TaggedDocument(words=['mary_miles_minter', 'schuyler_ladd', 'harry_blakemore', 'myra_brooks', 'ferdinand_tidmarsh', 'frank_devernon', 'russell_simpson', 'drama', 'edgar_jones', 'richard_barry'], tags=['lovely_mary_tt0006958']),
#  TaggedDocument(words=['edmund_breese', 'arthur_hoops', 'jeanette_horton', 'john_mahon', 'evelyn_brent', 'drama', 'francis_j._grandon', 'aaron_hoffman', 'robert_w._service'], tags=["the_lure_of_heart's_desire_tt0006992"]),
#  TaggedDocument(words=['clarence_burton', 'franklin_ritchie', 'george_webb', 'eugenie_forde', 'winifred_greenwood', 'roy_stewart', 'drama', 'edward_sloman', 'karl_r._coolidge'], tags=['lying_lips_tt0006994']),
#  TaggedDocument(words=['wilfred_lucas', 'herbert_beerbohm_tree', 'constance_collier', 'spottiswoode_aitken', 'drama', 'history', 'john_emerson', 'william_shakespeare', 'anita_loos'], tags=['macbeth_tt0006995']),
#  TaggedDocument(words=['lydia_yeamans_titus', 'anna_held', 'page_peters', 'herbert_standing', 'forrest_stanley', 'comedy', 'frank_lloyd', 'elliott_j._clawson', 'pierre_veber', 'maurice_hennequin', 'jose_g._levy'], tags=['madame_la_presidente_tt0007000']),
#  ...]

# %%
random.seed = 400
[random.shuffle(data.words) for data in train_data]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]

# %%
random.shuffle(train_data)

# %%
train_data[8]
# Out:
# TaggedDocument(words=['alena_bazalová', 'lucie_boksteflová', 'jakub_smíd', 'ivana_chýlková', 'denisa_baresová', 'drama', 'tereza_voriskova'], tags=['laputa_tt4037976'])

# %%
cores = multiprocessing.cpu_count()
#Configure and train the model
#model = gensim.models.doc2vec.Doc2Vec(dm= 0, vector_size= 300, window= 10, min_count=1, workers=cores, epochs= 100)
#model.build_vocab(train_data)
#model.train(train_data, total_examples=len(train_data) , epochs=model.epochs)
#save the model
cores = multiprocessing.cpu_count()
model = gensim.models.doc2vec.Doc2Vec(dm= 0, dbow_words=1, vector_size= 100, 
                                      hs=0 ,min_count=5,
                                      workers=cores, epochs= 50, sample=0,
                                      ns_exponent=(-3), negative=20, window_size= 10000)
#model.build_vocab(train_data)
#model.train(train_data, total_examples=len(train_data) , epochs=model.epochs)
model.save("../models/exp4/model")
# Out:
# 2020-12-05 01:19:55,826 : INFO : saving Doc2Vec object under ../models/exp4/model, separately None
# 2020-12-05 01:19:55,831 : INFO : saved ../models/exp4/model

# %%
#model = Doc2Vec.load('models/exp4/model')

# %%
words_vectors = model.wv
#get the docs vectors represenation
docs_vectors = model.docvecs

# %%
print(words_vectors.similarity("adam_sandler", "jennifer_aniston"))
print(words_vectors.similarity('douglas_hickox','cy_endfield'))

# %%
sent = helper_fn.find_movie_sent_by_id('harry_potter_and_the_sorcerer\'s_stone_tt0241527',movies_df)
print(sent[0])
infered_movie = model.infer_vector(sent[0])
similar_to_infered = docs_vectors.most_similar([infered_movie], topn=20)

print(*similar_to_infered, sep='\n')

print(helper_fn.find_movie_by_id('alone_tt3838034', movies_df).movie_sentence)

# %%
docs_vectors.most_similar(['spider-man_tt0145487'])

# %%
tsne_model = TSNE(n_jobs=4,
                  early_exaggeration=4,
                  n_components=2,
                  verbose=1,
                  random_state=2018,
                  n_iter=300)
#tsne_d2v = tsne_model.fit_transform(model.docvecs.vectors_docs)

# %%
doc_tags = list(model.docvecs.doctags.keys())
sample_tags= doc_tags[0:1000]
sample_docs = model[sample_tags]

# %%
sample_tags

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(sample_docs)
df = pd.DataFrame(X_tsne, index= sample_tags, columns=['x', 'y'])

# %%
X = model.wv[model.wv.vocab][0:10000]

tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X)

plt.scatter(X_tsne[:, 0], X_tsne[:, 1])
plt.show()

# %%
X_tsne.

# %%
tsne_d2v

plt.scatter(X_tsne[:, 0], X_tsne[:, 1])
plt.show()

# %%
def tsne_plot_word2vec(model):
    "Creates and TSNE model and plots it"
    labels = []
    tokens = []
    

    for word in model.wv.vocab[0:5000]:
        tokens.append(model[word])
        labels.append(word)
    
    tsne_model = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
    new_values = tsne_model.fit_transform(tokens)

    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
        
    plt.figure(figsize=(16, 16)) 
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        plt.annotate(labels[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    plt.show()

# %%
movies_df.isnull().any()

# %%
movies_df.describe

# %%
def find_in_movie_sent(search_list, row):
 #   print(row)
    if all(elem in row['movie_sentence']  for elem in search_list):
        return(row['movie_id'])
    else:
        return False
        
search_list=[ 'adventure', 'family','chris_columbus', 'j.k._rowling']
x=movies_df.apply(lambda row: find_in_movie_sent(search_list, row),axis=1)
#doc_tags =[]
for item in x:
    if item != False:
        doc_tags.append(item)

# %%
doc_tags

# %%
def tsne_plot(sample_tags, model):
    "Creates and TSNE model and plots it"
    labels = []
    tokens = []
    
    for doc in sample_tags:
        tokens.append(model[doc])
        labels.append(doc)
    
    tsne_model = TSNE(perplexity=5, n_components=2, init='pca', n_iter=10000, random_state=23)
    new_values = tsne_model.fit_transform(tokens)

    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
        
    plt.figure(figsize=(16, 16)) 
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        plt.annotate(labels[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    plt.show()

# %%
tsne_plot(list(set(tags)),model)
#docs_vectors.doctags

# %%
#model['going_overboard_tt0096870']
sim = docs_vectors.most_similar([model['billy_madison_tt0112508']])

# %%
tags=[] 
for id, similarity in sim:
    tags.append(id)

# %%
print(*doc_tags, sep='\n')

# %%
movie_sent_dict = dict(zip(movies_df.movie_id, movies_df.movie_sentence))

# %%
target_id = 'the_hunger_games_tt1392170'
n_items= 5
treshold=.4
data_size= 10

topn_list = model.docvecs.most_similar([target_movie_id], topn= n_items + 1)
#remove the target movie from the list
for idx, sim in enumerate(topn_list):    
    if sim[0] == target_id:        
        topn_list.pop(idx)
#(topn_list.pop(idx) if (topn_list[0] == target_movie_id ) for idx, sim in enumerate(topn_list))
precision_df = calculate_precision(target_id, topn_list, movie_sent_dict, treshold)

# %%
model.docvecs.most_similar([model[target_id]], topn=5+1)

# %%
model.docvecs.most_similar([target_id], topn=5)

# %%
random.seed = 400
n_items= 5
treshold=.44
data_size= 100
random.seed = 150
dict_keys = list(movie_sent_dict.keys())
random.shuffle(dict_keys)
movie_id_list = random.sample(dict_keys, data_size)
#movie_id_list=["the_hunger_games_tt1392170", "harry_potter_and_the_sorcerer's_stone_tt0241527"]
precision_df = calculate_precision_data_sample(5 , 4 ,movie_id_list, movie_sent_dict, treshold )
#movie_id_list

precision_df

# %%
docs_vectors.most_similar('harry_potter_and_the_sorcerer\'s_stone_tt0241527')
docs_vectors.most_similar('survivor_tt3247714')

# %%
movies_df.sample(frac=1)

# %%
sample_movies_df = movies_df.loc[movies_df.apply(lambda movie: True if ('romance' in movie['genre']) 
                                                 and ('comedy' in movie.genre) and ('adam_sandler' in movie.actor_name) else False, axis=1)]

# %%
sample_movies_df[['title','genre','actor_name','director_name','writer_name']]

# %%
#drama_movies_df = movies_df.loc[movies_df.genre.apply(lambda genre: True if 'drama' in genre else False)]

common_attrs_df= pd.DataFrame(columns=['movie_id','actors_cnt', 'directors_cnt','writers_cnt','genres_cnt','total_cnt'])

sample_movies_df.reset_index(drop=True, inplace=True)
print(query_movie_id)
query_movie_id= sample_movies_df.iloc[2].movie_id

common_attrs_df= common_attrs_df.append(sample_movies_df.progress_apply(lambda row: find_common_attrs(sample_movies_df,query_movie_id, row.movie_id), axis=1)
                                        ,ignore_index = True)

print(common_attrs_df)

# %%
sample_movies_df = movies_df.loc[movies_df.apply(lambda movie: True if ('romance' in movie['genre']) 
                                                 and ('comedy' in movie.genre) and ('adam_sandler' in movie.actor_name) else False, axis=1)]

common_attr_matrix = sample_movies_df.apply(lambda row: find_common_attrs_in_list(sample_movies_df, row.movie_id, cols), axis=1)
common_attr_matrix.set_index('title', inplace= True)

# %%
common_attr_matrix

# %%
#common_attr_matrix = common_attr_matrix.rename_axis(index=labels)

# %%
common_attrs_df = common_attrs_df[common_attrs_df.movie_id != query_movie_id]

# %%
common_attrs_df[common_attrs_df.total_cnt == common_attrs_df.total_cnt.max()]

# %%
docs_vectors.most_similar('the_wedding_singer_tt0120888', topn=30)

# %%
helper_fn.find_movie_sent_by_id('a_night_at_the_roxbury_tt0120770',movies_df)

# %%
helper_fn.find_movie_sent_by_id('the_wedding_singer_tt0120888',movies_df)

# %%
helper_fn.find_movie_sent_by_id('mr._deeds_tt0280590',movies_df)

# %%
find_common_attrs(movies_df,'the_wedding_singer_tt0120888', 'mr._deeds_tt0280590')

# %%
find_common_attrs(movies_df,'the_wedding_singer_tt0120888', 'a_night_at_the_roxbury_tt0120770')

# %%
def find_common_attrs_dict(movies_df,query_movie_id, search_movie_id):
    query_movie= movies_df[movies_df.movie_id == query_movie_id]
    search_movie= movies_df[movies_df.movie_id == search_movie_id]
    
    common_actors= count_sim(query_movie, search_movie, 'actor_name')
    common_directors= count_sim(query_movie, search_movie, 'director_name')
    common_writers= count_sim(query_movie, search_movie, 'writer_name')
    common_genres= count_sim(query_movie, search_movie, 'genre')
    
    common_dict = {search_movie_id: common_actors+common_directors+common_writers+common_genres}
    return common_dict

# %%
    common_attrs_dict=[]
    common_attrs_dict = [movies_df.progress_apply(lambda row: find_common_attr(movies_df,query_movie_id, row.movie_id), axis=1)]

# %%
drama_movies_df = movies_df.loc[movies_df.genre.apply(lambda genre: True if 'drama' in genre else False)]

# %%
len(drama_movies_df)
